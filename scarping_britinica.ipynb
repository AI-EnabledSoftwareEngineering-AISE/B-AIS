# %%
import requests
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession
import pandas as pd
from numpy import random
from time import sleep
import glob
import json
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")

# %%
not_stemmed_word = pd.read_csv("air_partial_data_based_wiki_score.csv")
not_stemmed_word
# Out:
#                word  similarity
# 0          airplane    0.729003
# 1             plane    0.691475
# 2               jet    0.675648
# 3        helicopter    0.637499
# 4           fighter    0.631056
# ..              ...         ...
# 695           alate         NaN
# 696  design process         NaN
# 697        flysheet         NaN
# 698  papilionaceous         NaN
# 699     world war i         NaN
#
# [700 rows x 2 columns]

# %%
# filtred_words1 = []
filtred_words =  not_stemmed_word["word"].tolist()
len(filtred_words)
# Out:
# 700

# %%
not_stemmed_word = pd.read_csv("not_stemmed_word_based_wiki_score.csv")
not_stemmed_word
# Out:
#              word  similarity
# 0         vehicle    0.765537
# 1           truck    0.735062
# 2          driver    0.711478
# 3         driving    0.644223
# 4        vehicles    0.632800
# ...           ...         ...
# 1047      there's         NaN
# 1048   governor's         NaN
# 1049     mother's         NaN
# 1050  passenger's         NaN
# 1051         he's         NaN
#
# [1052 rows x 2 columns]

# %%
not_stemmed_word = pd.read_csv("ped_not_stemmed_word_based_wiki_score.csv")
not_stemmed_word
# Out:
#             word  similarity
# 0        walkway    0.611893
# 1      sidewalks    0.547940
# 2      underpass    0.546047
# 3          lanes    0.545156
# 4       overpass    0.538890
# ..           ...         ...
# 407      hobbler         NaN
# 408    pointduty         NaN
# 409    swaggerer         NaN
# 410      gumwood         NaN
# 411  crossstreet         NaN
#
# [412 rows x 2 columns]

# %%
filtred_words1 = []
word_list =  not_stemmed_word["word"].tolist()
for el in word_list:
    if el.endswith("'s"):
        filtred_words1.append(el[:-2])
    else:
        filtred_words1.append(el)

# %%
len(filtred_words1)
# Out:
# 412

# %%
words_in_car_set = [
 'access',
 'accident',
 'accidents',
 'analysis',
 'areas',
 'auto',
 'automobile',
 'bicycle',
 'bridge',
 'carriage',
 'case',
 'city',
 'construction',
 'control',
 'day',
 'design',
 'distance',
 'dogs',
 'door',
 'downtown',
 'driver',
 'end',
 'fact',
 'highway',
 'hours',
 'injury',
 'interior',
 'legs',
 'light',
 'line',
 'lines',
 'lot',
 'man',
 'mile',
 'motor',
 'night',
 'number',
 'pace',
 'parking',
 'parks',
 'part',
 'passenger',
 'problem',
 'prowl',
 'road',
 'safety',
 'shadow',
 'side',
 'sight',
 'sound',
 'stream',
 'street',
 'style',
 'system',
 'time',
 'traffic',
 'travel',
 'trip',
 'trips',
 'vehicle',
 'vehicles',
 'vehicular',
 'view',
 'walk',
 'world'
]

# %%
# filtred_words2 = []
dup_words = []
for check_start in filtred_words1:
    res=[value for value in filtred_words1 if value[:-1].lower() == check_start.lower() and value.endswith("s")]
    if res:
#         print(check_start, res)
        dup_words.extend(res)
dup_words
# Out:
# ['crosswalks',
#  'malls',
#  'bridges',
#  'sidewalks',
#  'tunnels',
#  'roads',
#  'plazas',
#  'lanes',
#  'streets',
#  'vehicles',
#  'precincts',
#  'pathways',
#  'paths',
#  'routes',
#  'buildings',
#  'areas',
#  'miles',
#  'accidents',
#  'zones',
#  'collisions',
#  'ways',
#  'citys',
#  'hours',
#  'lines',
#  'excursions',
#  'guides',
#  'levels',
#  'spaces',
#  'nights',
#  'movements',
#  'adults',
#  'warnings',
#  'deaths',
#  'trips',
#  'exercises',
#  'patterns',
#  'mornings',
#  'students',
#  'volumes',
#  'childs',
#  'times',
#  'tours',
#  'types',
#  'womens',
#  'chances',
#  'forces']

# %%
dup_words + words_in_car_set
# Out:
# ['crosswalks',
#  'malls',
#  'bridges',
#  'sidewalks',
#  'tunnels',
#  'roads',
#  'plazas',
#  'lanes',
#  'streets',
#  'vehicles',
#  'precincts',
#  'pathways',
#  'paths',
#  'routes',
#  'buildings',
#  'areas',
#  'miles',
#  'accidents',
#  'zones',
#  'collisions',
#  'ways',
#  'citys',
#  'hours',
#  'lines',
#  'excursions',
#  'guides',
#  'levels',
#  'spaces',
#  'nights',
#  'movements',
#  'adults',
#  'warnings',
#  'deaths',
#  'trips',
#  'exercises',
#  'patterns',
#  'mornings',
#  'students',
#  'volumes',
#  'childs',
#  'times',
#  'tours',
#  'types',
#  'womens',
#  'chances',
#  'forces',
#  'access',
#  'accident',
#  'accidents',
#  'analysis',
#  'areas',
#  'auto',
#  'automobile',
#  'bicycle',
#  'bridge',
#  'carriage',
#  'case',
#  'city',
#  'construction',
#  'control',
#  'day',
#  'design',
#  'distance',
#  'dogs',
#  'door',
#  'downtown',
#  'driver',
#  'end',
#  'fact',
#  'highway',
#  'hours',
#  'injury',
#  'interior',
#  'legs',
#  'light',
#  'line',
#  'lines',
#  'lot',
#  'man',
#  'mile',
#  'motor',
#  'night',
#  'number',
#  'pace',
#  'parking',
#  'parks',
#  'part',
#  'passenger',
#  'problem',
#  'prowl',
#  'road',
#  'safety',
#  'shadow',
#  'side',
#  'sight',
#  'sound',
#  'stream',
#  'street',
#  'style',
#  'system',
#  'time',
#  'traffic',
#  'travel',
#  'trip',
#  'trips',
#  'vehicle',
#  'vehicles',
#  'vehicular',
#  'view',
#  'walk',
#  'world']

# %%
filtred_words = list(set(filtred_words1) - set(dup_words + words_in_car_set))
len(filtred_words)
# Out:
# 307

# %%
filtred_words
# Out:
# ['pattern',
#  'roadhog',
#  'pavementartist',
#  'slogger',
#  'routine',
#  'plaintiff',
#  'interstate',
#  'racewalking',
#  'paviage',
#  'fatalities',
#  'passersby',
#  'walkabout',
#  'footstep',
#  'underpass',
#  'movement',
#  'majority',
#  'ambler',
#  'landscaped',
#  'route',
#  'edge',
#  'motorist',
#  'hiker',
#  'mankind',
#  'quality',
#  'district',
#  'foot',
#  'subwaystation',
#  'non',
#  'child',
#  'traversable',
#  'treader',
#  'chance',
#  'walking',
#  'island',
#  'cobblestone',
#  'bicyclerack',
#  'scenicroute',
#  'character',
#  'skateboards',
#  'pattens',
#  'women',
#  'development',
#  'facilities',
#  'corridor',
#  'maindrag',
#  'crossstreet',
#  'status',
#  'trafficlane',
#  'trudge',
#  'heart',
#  'pathway',
#  'bystander',
#  'prose',
#  'merit',
#  'life',
#  'mall',
#  'crosswalk',
#  'treelawn',
#  'support',
#  'energy',
#  'sensation',
#  'accessroad',
#  'type',
#  'task',
#  'stalker',
#  'cycle',
#  'comparison',
#  'gate',
#  'streetsign',
#  'west',
#  'tramper',
#  'railwayline',
#  'verse',
#  'crashbarrier',
#  'entrance',
#  'passerby',
#  'sheltered',
#  'interference',
#  'bicyclist',
#  'blindcurve',
#  'overpass',
#  'block',
#  'yellowline',
#  'behavior',
#  'separation',
#  'path',
#  'intoxicated',
#  'protected',
#  'rambler',
#  'pastures',
#  'totterer',
#  'south',
#  'realism',
#  'elevated',
#  'soul',
#  'activity',
#  'bike',
#  'violation',
#  'traveler',
#  'zone',
#  'country',
#  'relation',
#  'pedestriantraffic',
#  'negligence',
#  'trafficcircle',
#  'form',
#  'hobbler',
#  'curbless',
#  'footpath',
#  'pawn',
#  'saunter',
#  'running',
#  'variety',
#  'safetyisland',
#  'congested',
#  'lack',
#  'motorized',
#  'hiking',
#  'study',
#  'flounce',
#  'belishabeacon',
#  'tunnel',
#  'underpasses',
#  'injuries',
#  'area',
#  'portion',
#  'tour',
#  'obstruction',
#  'circulation',
#  'account',
#  'permanentway',
#  'trafficcop',
#  'prosy',
#  'exercise',
#  'fashion',
#  'creation',
#  'gumwood',
#  'morning',
#  'naturestrip',
#  'manner',
#  'frontageroad',
#  'precinct',
#  'robinson',
#  'pavement',
#  'death',
#  'tollcollector',
#  'rightofway',
#  'crossings',
#  'tree',
#  'london',
#  'stroll',
#  'cyclist',
#  'amenities',
#  'woman',
#  'pointduty',
#  'rights',
#  'boots',
#  'wheelchair',
#  'swaggerer',
#  'plodder',
#  'shuffler',
#  'tripper',
#  'roadsurface',
#  'approach',
#  'volume',
#  'subwaytrain',
#  'experience',
#  'tollbar',
#  'walkway',
#  'link',
#  'adult',
#  'eastbound',
#  'gateless',
#  'gait',
#  'servicearea',
#  'warning',
#  'trafficisland',
#  'value',
#  'passer-by',
#  'staggerer',
#  'overpasses',
#  'protégé',
#  'space',
#  'perambulation',
#  'force',
#  'wayfarer',
#  'stroller',
#  'pedestrianize',
#  'density',
#  'footbridge',
#  'stamper',
#  'bedroomcommunity',
#  'childhood',
#  'property',
#  'powers',
#  'provision',
#  'percent',
#  'connections',
#  'tollbridge',
#  'skills',
#  'reverie',
#  'network',
#  'emphasis',
#  'lives',
#  'arterialroad',
#  'refuge',
#  'series',
#  'streetcorner',
#  'wards',
#  'hike',
#  'persons',
#  'traveller',
#  'limper',
#  'roundabout',
#  'factors',
#  'scale',
#  'plaza',
#  'collision',
#  'hardshoulder',
#  'promenade',
#  'mode',
#  'vehiculartraffic',
#  'passage',
#  'analyses',
#  'building',
#  'bark',
#  'yorks',
#  'busdepot',
#  'europe',
#  'playmates',
#  'uninteresting',
#  'passer',
#  'trolleycar',
#  'year',
#  'nature',
#  'marcher',
#  'shopping',
#  'viatecture',
#  'signals',
#  'neighborhoods',
#  'gibe',
#  'statue',
#  'concourse',
#  'duty',
#  'flow',
#  'kind',
#  'taxistand',
#  'wheelaround',
#  'ambulatory',
#  'town',
#  'dress',
#  'trafficwarden',
#  'air',
#  'car',
#  'transportationsystem',
#  'solace',
#  'amble',
#  'student',
#  'level',
#  'sage',
#  'sense',
#  'effect',
#  'environment',
#  'transit',
#  'maze',
#  'thoroughfare',
#  'strider',
#  'bed',
#  'walkable',
#  'attention',
#  'crusoe',
#  'pedestrial',
#  'activities',
#  'guide',
#  'cantileverbridge',
#  'amount',
#  'drivearound',
#  'excursion',
#  'sidewalk',
#  'reduction',
#  'railroadtrack',
#  'arterial',
#  'story',
#  'footer',
#  'businessdistrict',
#  'feats',
#  'journey',
#  'transportation',
#  'hour',
#  'way',
#  'footway',
#  'vehiculation',
#  'localroad',
#  'carson',
#  'walker',
#  'gephyrophobia',
#  'undergroundrailway',
#  'pedestrianisation',
#  'score',
#  'survey',
#  'earthbound',
#  'purposes',
#  'canoe',
#  'oncoming',
#  'prosaic',
#  'lane',
#  'peripatetic']

# %% [markdown]
# ## Do not use google api !!
# there is a limitation(100 req per day) for number of requests!

# %% [markdown]
# ## just for demo use next cell
# ```python
# def get_google_search_results(query="What is car?"):
#     starts = list(x for x in range(1,100,10))
#     res_dict_lsit = []
#     for start in starts :
#         API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
#     #     SEARCH_ENGINE_ID = "e714535f954174f5d"
#         SEARCH_ENGINE_ID = "13581eb0fad555f88"
#
# #         query = f"What is {word}?"
#
#         url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
#
#         params = {'num': 10, 'start': start}
#
#         res = requests.get(url, params=params).json()
#
#         res_dict_lsit.append(res)
#
#     #     print(json.dumps(res, indent=4, sort_keys=True))
#     #     break
#     return res_dict_lsit
#
# res_dict_lsit = get_google_search_results(query="What is car?")
# def get_link(res_dict_lsit):
#     britannica_links = []
#     for res in res_dict_lsit:
#         try:
#             items = res['items']
#             for item in items:
#                 title = item['title']
#                 print(title)
#                 print(item['link'])
#                 britannica_links.append(item['link'])
#         except KeyError:
#           print(json.dumps(res, indent=4, sort_keys=True))
#     return britannica_links
# ```

# %%
def get_google_search_results(word):
    print(f"search google for {word}")
    starts = list(x for x in range(1,100,10))
    res_dict_lsit = []
    for start in starts :
        API_KEY = "AIzaSyD8oV9Vs8yjNPLAjWPe6emSZf1E865K7uY"
    #     SEARCH_ENGINE_ID = "e714535f954174f5d"
        SEARCH_ENGINE_ID = "13581eb0fad555f88"

        query = f"What is {word}?"

        url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"

        params = {'num': 10, 'start': start}

        res = requests.get(url, params=params).json()

        res_dict_lsit.append(res)

    #     print(json.dumps(res, indent=4, sort_keys=True))
    #     break

    britannica_links = []
    for res in res_dict_lsit:
        items = res['items']
        for item in items:
            britannica_links.append(item['link'])
    return britannica_links

# %%
def britannica_search(word):
    print(f"search britannica for {word}")
    # to search
    query = f"what is aircraft {word}? site:britannica.com"
    
    p_time = int(random.uniform(3, 7))
    sleep(p_time)
    
    britannica_links = []
    for j in search(query, tld="com", lang='en', num=10, start=0, stop=100, pause=p_time):
        britannica_links.append(j)
    
    return britannica_links

# %%
def scarpe_links(britannica_links):
    # get all link related to a cocept
    all_links = []
    for lin in britannica_links:
        all_links.append(lin)
        # create an HTML Session object
        session = HTMLSession()
        # Use the object above to connect to needed webpage
        resp = session.get(lin)
        for u in resp.html.absolute_links:
            if lin in u and u != lin:
                all_links.append(u)
    #             print(u)
    return all_links

# %%
extracted_links = dict()
extracted_words = []

# %%
print(len(filtred_words))
print(len(list(set(filtred_words) - set(extracted_words))))
# Out:
# 700
# 0

# %%
len(extracted_words)
# Out:
# 700

# %%
search_words = list(set(filtred_words) - set(extracted_words))
len(search_words)
# Out:
# 0

# %%
while(search_words):
    search_words = list(set(filtred_words) - set(extracted_words))
    w_count = 0
    
    for word in search_words:
        w_count = w_count + 1
        if w_count == 5:
            break
        brit_links = britannica_search(word)
        extracted_words.append(word)
        extracted_links[word] = brit_links
    print(f"remaining words count: {len(list(set(filtred_words) - set(extracted_words)))}")
    sleep(20 * 60)

# %%
print(len(extracted_words))
print(len(list(set(filtred_words) - set(extracted_words))))
# Out:
# 700
# 0

# %%
import json

with open('data/britannica_l1_aviation_link.json', 'w') as fp:
    json.dump(extracted_links, fp)

# %%
with open('data/britannica_l1_car_link.json', 'w') as fp:
    json.dump(extracted_links, fp)

# %%
with open('data/britannica_l1_car_link.json', 'r') as fp:
    data = json.load(fp)

# %%
with open('data/britannica_l1_ped_link.json', 'r') as fp:
    data = json.load(fp)

# %%
with open('data/britannica_l1_aviation_link.json', 'r') as fp:
    data = json.load(fp)

# %%
! mkdir -p data/britanica_texts/aviation
! ls data/britanica_texts/aviation

# %%
[f.rsplit('/', 1)[1].split('.',1)[0] for f in glob.glob("data/britanica_texts/aviation/*.txt")]
# Out:
# ['B-10',
#  'Walleye',
#  'professional-liability-insurance',
#  'Modulators-and-demodulators',
#  'Islander',
#  'Donald-Kent-Slayton',
#  'United-States-Army-Air-Corps',
#  '11',
#  'Mobile-Alabama',
#  'Katyusha',
#  'Air-India-Flight-182-disaster',
#  'pneumonia',
#  'Functions',
#  'Red-Wing-airplane',
#  'tropical-cyclone',
#  '15',
#  'imaging-radar',
#  'overhead-camshaft-engine',
#  'Battle-of-Midway',
#  'Malaysia-Airlines-flight-370-disappearance',
#  '273129',
#  'Tuskegee-Airmen',
#  'cell-phone',
#  'Ramzi-Ahmed-Yousef',
#  'RQ-5-Hunter',
#  'Direct-current-generators',
#  'Engagement-with-South-Korea-and-the-United-States',
#  'AN-2',
#  'BTR-60',
#  'convoy-naval-operations',
#  'launch-vehicle',
#  'Area-51-military-air-force-base-alien-video',
#  'www',
#  'Charles-Stewart-Mott',
#  'Boeing-777',
#  'What-did-Alexander-Graham-Bell-invent',
#  'are-there-laws-on-the-high-seas',
#  'John-Hunter-British-surgeon',
#  'Guadalcanal-and-Papua',
#  'William-Crookes',
#  'X-13-Vertijet',
#  'warning-system',
#  'parallel-runway',
#  'Strategy-and-wars-of-national-liberation',
#  'Sully-film',
#  'John-L-Worden',
#  'D-B-Cooper',
#  'gas-balloon',
#  'cockpit',
#  'conservation-of-linear-momentum',
#  'Tim-Peake',
#  'H-L-Hunley',
#  'Trident-II',
#  'deflected-thrust-aircraft',
#  '80',
#  'Stratocruiser',
#  'optical-system',
#  '231425',
#  'iraq-invades-kuwait',
#  'James-Joseph-Sylvester',
#  '41',
#  'B-52',
#  'The-first-airlines',
#  'Lakeland',
#  'Apogee-Inc',
#  'Nike-Sprint',
#  'image-intensifier',
#  'solar-neutrino-problem',
#  'storage-battery',
#  '353388',
#  'bug-computing',
#  'special-election-issue-the-candidates-on-the-environment-and-animal-welfare',
#  '336617',
#  'Otto-von-Kotzebue',
#  'Great-Eastern',
#  'Sutton-Vane',
#  'September-21',
#  'School-of-Special-Flying',
#  'Architecture-and-organization',
#  'fertilizer',
#  'JC-Penney-Corporation-Inc',
#  'May-2-2021',
#  'digital-forensics',
#  'Pilcher-Hawk',
#  '273845',
#  'dreadnought-battleship-class',
#  '274829',
#  'International-Civil-Aviation-Organization',
#  'Operation-High-Jump',
#  'Metal-matrix-and-ceramic-matrix-composites',
#  'Special-photosensitive-systems',
#  'International-Academy-of-Astronautics',
#  'diamond-formation',
#  'Honeywell-International-Inc',
#  '126228',
#  'military-base',
#  'Liberal-Kansas',
#  'World-War-II',
#  '235647',
#  'Europe-after-World-War-II',
#  'Pz-IB',
#  'Doppler-frequency-shift',
#  'Supercell-storms',
#  'media?assemblyId=51240',
#  '275077',
#  'demilitarized-zone-Korean-peninsula',
#  '251023',
#  '16675-8',
#  'digital-video-recorder',
#  'ballistic-missile',
#  '9-memorials-and-monuments-in-the-united-states',
#  'CG-4',
#  'Alaskan-Mountains',
#  'Kettering-Ohio',
#  'Enomoto-Takeaki',
#  'Tupolev-Tu-144',
#  'John-Harrison-British-horologist',
#  'Otto-engine',
#  'pro-and-con-gold-standard',
#  'Animation-speed-of-light-laser',
#  'Northwest-Airlines-Inc',
#  '61',
#  'sport-parachute',
#  'The-Iran-Iraq-War',
#  '273759',
#  'Ship-maneuvering-and-directional-control',
#  'induced-drag',
#  'Francis-Garnier',
#  '121',
#  'infographic-attack-Pearl-Harbor-December-7-1941',
#  'Jacob-Jones',
#  'FQM-151-Pointer',
#  '134',
#  'Santos-Dumont-No-14-bis',
#  'Charles-Adolphe-Wurtz',
#  '236735',
#  'Yitzhak-Rabin',
#  'Influence-of-chemoreception-in-humans',
#  'California-since-c-1900',
#  'Waves-on-deep-water',
#  'heading',
#  '191',
#  'unducted-fan',
#  'Raymond-Saulnier',
#  'William-E-Boeing',
#  'Maximilian-Graf-von-Spee',
#  'Everett-Strait-Hughes',
#  'weapon-of-mass-destruction',
#  'Air-Force-One',
#  'taw',
#  'Yuly-Borisovich-Khariton',
#  'Navigational-aids-lighting-and-marking',
#  'MiG-Soviet-aircraft',
#  'flying-wing',
#  'seismograph',
#  'United-Technologies-Corporation',
#  'Government-and-society',
#  'variable-geometry-wing',
#  'Imperial-Airways-Ltd',
#  'tailwind',
#  'Oscar-W-Underwood',
#  'Primary-batteries',
#  'forensic-science',
#  'Wright-brothers',
#  'aviation',
#  'X1-E-US-Air-Force-B-29-Edwards-Base-Oct-14-1947',
#  'technological-ingenuity',
#  'bombing-military-technology?oasmId=132983',
#  'General-arrangement',
#  'Uday-Hussein',
#  'Libya-Revolt-of-2011',
#  'bps-ssl-gsm-topic-153000-3000',
#  '277512',
#  '157',
#  'Pavel-O-Sukhoy',
#  'bps-ssl-gsm-topic-135000-3000',
#  'ice-skating',
#  'B-26-Invader',
#  'landside-facility',
#  '17291-8',
#  'Berlin-crisis-of-1961',
#  'John-Glenn',
#  'Great-Britain-ship',
#  'underwater-weapon',
#  'Limits-on-the-methods-and-means-of-war',
#  'baffle-engine-part',
#  'where-did-the-peace-sign-come-from',
#  'Blackburn-Buccaneer',
#  'Forestry',
#  'Westinghouse-Electric-Corporation',
#  'Battle-of-Leyte-Gulf',
#  'airside-facility',
#  'Stage-machinery',
#  'Novosibirsk-Russia',
#  'high-speed-photography',
#  '12',
#  'Soldiers-Pay',
#  'Hong-Kong-International-Airport',
#  'Economy-and-risk',
#  'Type-VIIC',
#  '2925',
#  'Defense-management-budgeting-deterrence',
#  'Jacques-Chirac',
#  'The-Satanic-Verses',
#  'Rudolf-Hess',
#  '274574',
#  'plug-bayonet',
#  'Defense-Production-Act',
#  'bejel',
#  'May-15',
#  'Blanche-Noyes',
#  'ylopl',
#  'Volvo-Aktiebolaget',
#  '275388',
#  'attitude-control',
#  'main?page=3',
#  'disk-brake',
#  'direct-coupling',
#  'Samuel-Kurtz-Hoffman',
#  'The-Antarctic-Treaty',
#  'Marine-One',
#  'press_sec_009',
#  'History-of-drawing',
#  'Eastern-Air-Lines-Inc',
#  'hydrazine-thrustor',
#  'waterspout',
#  'effects-of-plastics-on-the-environment',
#  '14974-8',
#  'Subroc',
#  'Air-India',
#  'Wilkins-Ice-Shelf',
#  'caterpillar-tractor',
#  'aerial-reconnaissance',
#  'steward',
#  'Economic-policy-changes',
#  'instrumentation-technology',
#  'Cloud-research',
#  '231469',
#  'a-reading-list-to-put-the-wikileaks-war-logs-in-context',
#  'turbo-train',
#  'KLIF',
#  'Humphrey-Gilbert',
#  'mathematical-programming',
#  'Robert-Alexander-Watson-Watt',
#  'Richard-von-Mises',
#  'bps-ssl-gsm-topic-195000-3000',
#  'aspects-life-microgravity-Earth',
#  'gyroscope',
#  '629969',
#  'daymark',
#  'Movement-of-thunderstorms',
#  'H2S',
#  'toy',
#  'Mosquitoes',
#  'bps-ssl-gsm-topic-198000-3000',
#  'plane-plastic-flow',
#  'University-of-Nebraska',
#  'Inland-marine-insurance',
#  'Hale-rocket',
#  'World-War-II-1939-45',
#  'critically-endangered-sea-turtles-get-a-much-needed-lift',
#  'giant-fulmar',
#  'spraying-and-dusting',
#  'He-111',
#  'hyperbolic-navigation-system',
#  'Claude-Grahame-White',
#  'airfoil',
#  'Years-of-crisis-1920-23',
#  'Shannon-Wells-Lucid',
#  'great-circle-route',
#  'National-Traffic-and-Motor-Vehicle-Safety-Act',
#  'strategic-missile',
#  'visibility-meteorology',
#  'electronic-countermeasure',
#  'fin-stabilizer',
#  '124761',
#  'heating-process-or-system',
#  'High-rise-construction-since-1945',
#  'Messerschmitt-AG',
#  'radio-altimeter',
#  'Faradays-discovery-of-electric-induction',
#  'Chris-Christie',
#  'Grand-Tour',
#  'The-Allied-landings-in-North-Africa',
#  'boundary-layer',
#  'borehole-deformeter',
#  'Light-carriers',
#  'bps-ssl-gsm-topic-183000-3000',
#  'Chieftain',
#  'AIM-9-Sidewinder',
#  'Imre-Brody',
#  'Lionel-Lukin',
#  'Harold-Rosen',
#  'Hitlers-war-or-Chamberlains',
#  '48',
#  '51085',
#  'Alkaline-storage-batteries',
#  'afterburner-mechanical-engineering',
#  'Convention-for-the-Suppression-of-Unlawful-Seizure-of-Aircraft',
#  'twin-plane',
#  'main?page=2',
#  'rhinegraves',
#  'Mirage-F-1',
#  'Injection-molding',
#  'Pauliniidae',
#  'infrasonics',
#  'Konstantin-Eduardovich-Tsiolkovsky',
#  'Scientific-eminence',
#  'Hans-Christian-Orsted',
#  'electrometer',
#  'Saint-Elmos-fire',
#  'sensitivity-of-an-instrument',
#  'ground-controller',
#  'Limitations-of-the-tank',
#  'in-line-engine',
#  'what-is-known-and-not-known-about-the-tunguska-event',
#  '273255',
#  'northern-fulmar',
#  'calendar',
#  'Los-Angeles-aircraft',
#  'cognitive-dissonance',
#  'balance-of-power',
#  'Thomas-Godfrey-North-American-inventor',
#  '233675',
#  '227385',
#  'commercial-aircraft',
#  'dod_brief107',
#  'William-Huggins',
#  'F-102-Delta-Dagger',
#  'titanium-processing',
#  'Longitude-measurements',
#  '5-unforgettable-moments-history-spaceflight-space-exploration',
#  'limb-darkening',
#  '127278',
#  'peripheral-jet',
#  'Palmdale',
#  '73',
#  'USS-Arizona',
#  'bps-ssl-gsm-topic-45000-3000',
#  'orthophotoscope',
#  'box-kite',
#  'Fritz-Zwicky',
#  'anthrax-disease',
#  'Job-description-aerospace-engineer',
#  'kiln-oven',
#  'Helldiver',
#  'landlines-Crossword-Puzzle',
#  'Hobart-Pasa',
#  'Niels-Juel',
#  'Atomic-power',
#  'apron-airport',
#  'Hurricane-Katrina',
#  'The-age-of-fighting-sail',
#  'Ilyushin-Il-2',
#  '181',
#  'Common-control-techniques',
#  'Stonington-Island',
#  'The-aeronautical-infrastructure',
#  'Wilbur-Wright',
#  'History-of-radar',
#  'shotgun-houses',
#  'muffler-engine-part',
#  'Donald-Malcolm-Campbell',
#  'The-Signal-Companies-Inc',
#  'quartermaster',
#  'Milledgeville',
#  'Chemical-etching-traditional-and-powderless-processes',
#  'pliers',
#  'sucoo',
#  '132',
#  'Pham-Tuan',
#  'Raphael-Semmes',
#  'Battle-of-Saint-Mihiel-1918',
#  'submarine-naval-vessel',
#  'peroxide',
#  'ribbon-microphone',
#  'Fletcher-Christian',
#  'Alan-B-Shepard-Jr',
#  'bps-ssl-gsm-topic-138000-3000',
#  'Allen-W-Dulles',
#  'reel-cinematography',
#  'Bottom-locomotion',
#  'Fieseler-Fi-156-Storch',
#  'nodal-plane',
#  'elevator-vertical-transport',
#  'Bravery',
#  '115',
#  'Jerome-C-Hunsaker',
#  'Souris-River',
#  'Yankee-Soviet-submarine-class',
#  'Grumman-Aerospace-Corporation',
#  'Isaac-Hull',
#  'DC-9',
#  '53',
#  'Alfred-C-Haynes',
#  'mast-ship-part',
#  '124764',
#  '325036',
#  'environmental-infrastructure',
#  'antiballistic-missile',
#  '51440',
#  'Secret-sharing',
#  'gilsonite',
#  'Tomahawk-ground-launched-cruise-missile',
#  'The-Atlantic-and-the-Mediterranean-1940-41',
#  'Postal-technology',
#  'Philo-Farnsworth',
#  'Filters',
#  'Modern-building-practices',
#  'Aer-Lingus',
#  '629045',
#  'Halifax-aircraft',
#  'Montgomery-Alabama',
#  'Interwar-developments',
#  'Leroy-Randle-Grumman',
#  'naval-warfare',
#  'Electric-clocks',
#  'The-20th-and-21st-centuries',
#  'Chuck-Yeager',
#  '276484',
#  'main?page=6',
#  'Khobar-Towers-bombing-of-1996',
#  'how-are-sports-chosen-for-the-olympics',
#  'VHF',
#  'Activities',
#  'Virgil-I-Grissom',
#  'Hamid-Karzai',
#  '312876',
#  'Macon-Georgia',
#  'Hermann-Goring',
#  'history-of-United-States',
#  'Projective-conic-sections',
#  'Mary-Jackson-mathematician-and-engineer',
#  'Flying-Tigers',
#  'Boris-Berezovsky',
#  'Civil-aircraft',
#  'Charles-Stark-Draper',
#  'satellite-communication',
#  'Continental-Airlines-Inc',
#  'tomelectric',
#  '276450',
#  '5-components-of-information-systems',
#  'flight-animal-locomotion',
#  'Transportation',
#  'France',
#  'Scapa-Flow',
#  'Elisha-Otis',
#  'catalytic-reforming',
#  'fin-engineering',
#  'Albert-Kesselring',
#  'Tactical-guided-missiles',
#  'voltage-regulator',
#  'James-Stockdale',
#  'Disorders-due-to-physical-agents',
#  'International-relations',
#  'International-Geophysical-Year',
#  'Michel-Chasles',
#  'electromagnetic-aircraft-launch-system',
#  'AS-14-Kedge',
#  'strategic-bombing',
#  'Sir-Reginald-Myles-Ansett',
#  '95',
#  'neutrality',
#  'Willimantic',
#  'V-2-rocket',
#  'Tobias-Furneaux',
#  'M1A1',
#  '239783',
#  'Nikita-Sergeyevich-Khrushchev',
#  'The-age-of-the-aircraft-carrier',
#  'refuse',
#  'reconnaissance',
#  '76',
#  '237184',
#  'animals-in-the-news-216',
#  'bps-ssl-gsm-topic-144000-3000',
#  '25244-8',
#  'Nuclear-propulsion',
#  'Dassault-Industries',
#  'what-is-a-neural-network-a-computer-scientistexplains',
#  'tooth-squeeze',
#  'parachute',
#  'J-Willard-Gibbs',
#  'Lufthansa-heist',
#  '352719',
#  'Standard-missile',
#  '315699',
#  'Stans',
#  'The-Nationalist-government-from-1928-to-1937',
#  'intermediate-range-ballistic-missile',
#  'all-american-history-quiz',
#  'Battle-of-the-Eastern-Solomons',
#  'Medicine-Lodge',
#  'continuous-combustion-engine',
#  'Alexander-Graham-Bell',
#  'look-campus-wind-tunnel-Wright-brothers-Massachusetts',
#  'SU-7-Fitter',
#  'Donald-Maclean',
#  'William-Barker-Cushing',
#  'perceptual-constancy',
#  'safety-chain-dog',
#  'Marcus-Aurelius-Mausaeus-Carausius',
#  'bombsight',
#  'francisca-weapon',
#  'Peter-Paul-Rubens',
#  'Nike-Hercules',
#  'Womens-Army-Corps',
#  'is-air-france-flight-447-lost-in-the-bermuda-triangle',
#  'optics',
#  'The-influence-of-behaviourism',
#  'Industry-processes',
#  'Tempest-British-aircraft',
#  'Battle-of-Britain-European-history-1940',
#  '272772',
#  'The-Eastern-Front-June-December-1944',
#  'Government-of-India-Act-of-1858',
#  '86',
#  'P-47',
#  'pilum',
#  'distributor',
#  'Amos-Whitney',
#  '4-kennedys-failure-at-the-bay-of-pigs-top-10-mistakes-by-us-presidents',
#  'Suez-Canal',
#  'Colleen-Moore',
#  'AWACS',
#  '260179',
#  'Labour-rule-after-Ben-Gurion',
#  '175',
#  'bps-ssl-gsm-topic-210000-3000',
#  'Germany-and-the-America-First-movement',
#  'Key-Terms-Titanic',
#  'automotive-ceramics',
#  'Frank-Baldwin-Jewett',
#  'Konrad-Wachsmann',
#  'George-Jones',
#  'T-55',
#  'thrust-propulsion',
#  'C-141',
#  '113',
#  'RQ-4-Global-Hawk',
#  'Admiralty-British-government',
#  '325557',
#  'mechanics',
#  'Boeing-367-80',
#  'Upper-level-winds',
#  'Police-work-as-an-occupation',
#  '275251',
#  'Polaroid-Corporation',
#  'Madrid',
#  '400108',
#  'Stuka',
#  'solid-propellant-motor',
#  'The-Flower-Children-2101574',
#  'Overview-Bird-Island-Seychelles',
#  'specific-power',
#  'Longview-Texas',
#  'Igor-Sikorsky',
#  'extravehicular-activity-backpack',
#  'sound-localization',
#  'Michael-Smith-American-astronaut',
#  '390850',
#  'main?page=10',
#  'The-generation-and-application-of-power-the-problem-of-propulsion',
#  'intifadah',
#  '277797',
#  'Palmach',
#  'elevator-aircraft-part',
#  'NATO-air-defense-ground-environment',
#  'Circular-orbits',
#  'augmentor-wing',
#  'drone',
#  'antitank-guided-missile',
#  'high-speed-engine',
#  'Education-and-training',
#  'Edmund-Fitzgerald',
#  'Atomic-time-scales',
#  '336226',
#  'larceny',
#  'Gossamer-Albatross',
#  'noise-acoustics',
#  'hang-gliding',
#  'geostationary-orbit',
#  'Henry-Bradwardine-Jackson',
#  'James-I-1603-25',
#  'cowl-aircraft-part',
#  '213',
#  'photogrammetry',
#  'cone-headed-grasshopper',
#  '275881',
#  'gyroscope-equation',
#  'iPhone-11-Pro',
#  'Alonso-Perez-de-Guzman-duque-de-Medina-Sidonia',
#  'Going-into-business',
#  'Louis-Sebastien-Lenormand',
#  'position-finding',
#  'bps-ssl-gsm-topic-93000-3000',
#  'Pentagon',
#  'R-J-Mitchell',
#  'government-budget',
#  'David-Stirling',
#  'Avion-III',
#  'YB-49',
#  'Impedance',
#  'bps-ssl-gsm-topic-39000-3000',
#  'Guerrilla-war-at-sea-the-submarine',
#  'Flapping-soaring-and-diving',
#  'Operation-Wrath-of-God',
#  'cogeneration',
#  'Zia-ul-Haq',
#  'Bartolomeu-Lourenco-de-Gusmao',
#  '317395',
#  'transportation-and-technology-firsts-quiz',
#  'polar-stratospheric-cloud',
#  'Transportation-Security-Administration',
#  'Mosquito-British-aircraft',
#  'stressed-skin-construction',
#  '232083',
#  'space-exploration',
#  'sodium-tetrahydridoborate',
#  'Eurofighter-Typhoon',
#  'test-laboratory',
#  'Nawaz-Sharif',
#  '277456',
#  'rotor-kite',
#  'chemical-propellant',
#  'invasive-species',
#  'Troposphere',
#  'SCR-270',
#  '112',
#  'history-of-France',
#  'bomber',
#  'slant-faced-grasshopper',
#  'light-fleet-carrier',
#  'Ahmad-Shuqayri',
#  'Revolutionary-period-and-statehood',
#  'fire-prevention-and-control',
#  'propfan',
#  'air-toxic',
#  'Fort-Scott',
#  'Shenzhou',
#  'dip-circle',
#  'bps-ssl-gsm-topic-24000-3000',
#  'bola',
#  'Trans-World-Airlines-Inc',
#  'day-tripping',
#  'DC-8',
#  'Oliver-North',
#  'De-Havilland-DH-4',
#  'hot-air-balloon',
#  'thyristor',
#  'Type-99-Val',
#  'Carl-Spaatz',
#  'catapult-military-weaponry',
#  'Medium-A',
#  'September-24',
#  'types-training-flight-simulators',
#  'European-Aeronautic-Defence-and-Space-Company',
#  'Philippe-Starck',
#  'Argonaut-proto-submarine',
#  'Measurement-of-the-field',
#  'The-attacks',
#  'Royal-Canadian-Air-Force',
#  'Hovercraft',
#  'Frank-Abney-Hastings',
#  '3551',
#  'D-Day-June-6-1944',
#  'aerial-rocket',
#  'sprocket',
#  'speciesism-in-three-uneasy-pieces',
#  'Excerpt-documentary-Loblolly-House-KieranTimberlake-Cellophane',
#  'tactical-guided-missile',
#  'Winners-of-the-Nobel-Prize-for-Chemistry-1846695',
#  'F-22-Raptor',
#  'Brussels-Airlines',
#  'Uruguayan-Air-Force-flight-571',
#  'Buildup-1943-44',
#  'Air-Force-One-enters-the-jet-age',
#  'rocket-jet-propulsion-device-and-vehicle',
#  'Eurocopter',
#  'jet-propulsion',
#  'Mike-Mullen',
#  'amphibious-airplane',
#  'Bombardier-Inc',
#  'fog',
#  'scarecrow-agriculture',
#  'voyage-charter',
#  'Andrea-Doria-Italian-ship',
#  'electric-generator',
#  'carbon-tetrachloride',
#  'Henry-Kent-Hewitt',
#  'beacon-device',
#  'Minden-Nebraska',
#  'casualty-insurance',
#  'command-guidance-system',
#  'Ivan-Bella',
#  'tiny-trackers-for-tiny-animals',
#  'SS-N-15',
#  'Constitutional-framework',
#  'Postwar-Europe',
#  'Roald-Amundsen',
#  'Kormoran',
#  'Computer-integrated-manufacturing',
#  '3341',
#  'typewriter',
#  'operating-system',
#  'consolidation-business',
#  'E-F-Schumacher',
#  'rotary-wing-aircraft',
#  'The-War-of-the-Worlds-novel-by-Wells',
#  'The-Third-Reich-1933-45',
#  'compass-card',
#  'EAA-AirVenture-Oshkosh',
#  'Mohammed-Atta',
#  'Waterways',
#  'antiship-missile',
#  'bps-ssl-gsm-topic-21000-3000',
#  '632913',
#  '326056',
#  'navigation-technology',
#  'job-description-of-a-patent-attorney-2183569',
#  'Litton-Industries-Inc',
#  '180',
#  '273873',
#  'Council-Grove',
#  'Battle-of-Atlanta',
#  'single-frequency-plane-wave',
#  'area-rule',
#  'air-engine',
#  'Maritime-and-hydraulic-engineering',
#  'reprisal',
#  'Atlantic-Conveyor',
#  'Thaddeus-Fairbanks',
#  'Zheng-He',
#  'Cheboygan',
#  'Pz-VI',
#  'Arctic-National-Wildlife-Refuge',
#  'ignition-system',
#  'Other-primary-battery-systems',
#  'latitude',
#  'Elisha-Kent-Kane',
#  'Lithium-batteries',
#  'Tsar-Bomba',
#  'Clyde-Vernon-Cessna',
#  'Guion-Bluford',
#  'Eskisehir',
#  'Fred-Haise',
#  'Columbus-Georgia',
#  'Birkbeck-College',
#  'Art-Arfons',
#  'Industrial-applications',
#  'stress-rupture-curve',
#  'Cargo-facilities',
#  'Achille-Lauro-hijacking',
#  'Kinds-of-power-yachts',
#  '54',
#  'tankette',
#  'Growth-in-the-20th-century',
#  '6-domestic-animals-and-their-wild-ancestors',
#  'suit-playing-cards',
#  'Beechcraft',
#  'heavy-aircraft',
#  '331255',
#  'Work-in-the-United-States',
#  'Ark-Royal',
#  'kamikaze-of-1274-and-1281',
#  'related',
#  'history-of-Iran',
#  'Husband-Edward-Kimmel',
#  '110',
#  '275070',
#  'Auguste-Chouteau',
#  'The-Cavern',
#  'Giulio-Douhet',
#  'Kitty-Hawk-North-Carolina',
#  'treading-water-on-iran',
#  '109',
#  'Fw-190A-2',
#  'RB211',
#  'Francis-Light',
#  'Brewsters-law',
#  'airspeed',
#  'Sir-George-Gabriel-Stokes-1st-Baronet',
#  '93',
#  'Plainfield-New-Jersey',
#  'cable-stayed-roof',
#  '253',
#  'Government-and-politics',
#  'January-20',
#  '292',
#  'hang-glider',
#  'bps-ssl-gsm-topic-87000-3000',
#  'A310',
#  'mechanization',
#  'Brendan-Gill',
#  'The-Soviet-advance-to-the-Oder-January-February-1945',
#  'Kokoda-Track-Campaign',
#  '31',
#  'surfactant',
#  '79',
#  'junction-box',
#  'bps-ssl-gsm-topic-36000-3000',
#  '237255',
#  'inclination-of-equator-to-orbit',
#  'Columbine-I',
#  'Spain-17th-century',
#  'space-tourism',
#  'flight-plan',
#  'World-War-I',
#  'Swissair-flight-111',
#  'captain-military-and-maritime-service-rank',
#  'Ferrimagnetic-materials',
#  'Seattle-Storm',
#  'Petroleum-products-and-their-uses',
#  '183943',
#  'distance-measuring-equipment',
#  'ethane',
#  'Kevlar',
#  'General-Dynamics-Corp',
#  'unit-train',
#  'Technology-strategy-and-the-outbreak-of-war',
#  'Merchants-Staplers',
#  'Esek-Hopkins',
#  'Fog-dissipation',
#  'Some-Uses-of-Over-and-Above-as-Prepositions',
#  'Bojinka-Plot',
#  'life-support-system-environmental',
#  'Little-America-research-station-Antarctica',
#  'Condor-Legion',
#  'air-mass',
#  'Space-applications',
#  'mass-spectroscope',
#  'Leonardo-da-Vincis-parachute-1704849',
#  'atomic-bombings-of-Hiroshima-and-Nagasaki',
#  '340312',
#  'piston-engine',
#  'Determining-the-hazard-potential-of-an-NEO',
#  'LCROSS',
#  'bps-ssl-gsm-topic-240000-3000',
#  'remanufacturing',
#  'stroke-mechanics',
#  'Rommels-final-offensive-in-Africa',
#  'Gregory-Jarvis',
#  '399584',
#  '390246',
#  'buck-and-wing',
#  'ACV-operation',
#  'shunt-excited-DC-generator',
#  'sunstroke',
#  'Night-Flight-by-Saint-Exupery',
#  'Harold-Gatty',
#  'Circular-motion',
#  'Operation-Desert-Sabre',
#  'Back-to-the-38th-parallel',
#  'bps-ssl-gsm-topic-159000-3000',
#  'electrotyping',
#  'Anatoly-Fyodorovich-Dobrynin',
#  'Japan-Aerospace-Exploration-Agency',
#  'gun-turret',
#  'Frederick-W-Smith',
#  'thermal-oxidation',
#  'Nicolas-Louis-Robert',
#  'Invasion-of-the-Soviet-Union-1941',
#  'control-system',
#  '8t-SdKfz-vehicle',
#  'fuel-air-explosive-bomb',
#  'July-16',
#  'Louise-McPhetridge-Thaden',
#  'Kurt-Lewin',
#  'James-Baker',
#  'The-Civil-War-and-Reconstruction',
#  'production-system',
#  'air-mass-thunderstorm',
#  'General-Motors-Corporation',
#  '183',
#  'Battle-of-France-World-War-II',
#  'DC-4',
#  'bps-ssl-gsm-topic-99000-3000',
#  'European-cinema',
#  'law',
#  'Enclosure-systems',
#  'Greenville-South-Carolina',
#  'Battle-of-Kursk',
#  'on-this-day-September-2',
#  'destroyer',
#  'zinc-chromate',
#  'iconoscope',
#  'revolving-beam-lighthouse',
#  'White-Knight',
#  'Jean-de-Hautefeuille',
#  '310005',
#  'grappling-hook',
#  'MiG-29',
#  'Women-in-Black',
#  'Toulouse-France',
#  'Harrier-airplane',
#  'Ilyushin-Il-76',
#  'Ader-Avion-III',
#  '151',
#  'Eugene-Schneider',
#  'space-perception',
#  'Robert-Crippen',
#  'Henry-Villard',
#  'bps-ssl-gsm-topic-132000-3000',
#  'MiG-15',
#  'Santa-Monica',
#  'Degradable-plastics',
#  'analog-computer',
#  'Claude-de-Forbin',
#  'infrared-sensor',
#  'flota',
#  'Boston-Latin-School',
#  'Military-regimes-and-the-Duvaliers',
#  '277062',
#  'mineral-chemical-compound',
#  '322983',
#  'Important-considerations',
#  'Horsa-aircraft',
#  'Pz-III',
#  'state_046',
#  'ironclad',
#  'symmetry-physics',
#  'hr2926_house_proc',
#  'schistosomiasis',
#  'mission',
#  '89401',
#  'Why-was-the-Concorde-retired',
#  'The-theodolite',
#  'San-Jose-California',
#  'Beryl-Markham',
#  'The-United-States-Navy',
#  'composite-propellant',
#  'why-do-airlines-overbook-seats-on-flights',
#  'square-mathematics',
#  'episode-You-Bet-Your-Life-Groucho-Marx',
#  'Ferdinand-Graf-von-Zeppelin',
#  'Wright-glider-of-1902',
#  'U-2',
#  'Lawrence-Dale-Bell',
#  'The-United-States-Marine-Corps',
#  'Electra-aircraft',
#  'Ramon-Magsaysay',
#  'Tsunami-warning-systems',
#  'weapon-platform',
#  'air-warfare',
#  'United-States-Naval-Academy',
#  'sabot-military-technology',
#  'embossing',
#  'Comet-airplane',
#  '27',
#  'Dumitru-Prunariu',
#  'weapon',
#  'Aleksandr-Fyodorovich-Mozhaysky',
#  'James-Smith-McDonnell',
#  'turretless-tank',
#  'reciprocating-engine',
#  'Hermes-ship',
#  'combustion-chamber',
#  'Cimon',
#  '277735',
#  'Modern-armour',
#  'missile-weapon',
#  'Subroto-Mukerjee',
#  'Strategic-bombing',
#  'Bf-110',
#  'loaded-dice',
#  'Vulcan-automatic-cannon',
#  'emission-control-system',
#  'Geoffrey-De-Havilland',
#  'air-force',
#  'Fort-Worth',
#  'Japan-Airlines',
#  'strike',
#  'From-World-War-I-to-1940',
#  '127357',
#  '6731',
#  'position-keeping',
#  'Peter-Barlow',
#  'Lock-Haven',
#  'Montgomery-in-the-desert',
#  'KC-135-Stratotanker',
#  'flightless-bird',
#  '68',
#  'Peace-of-Westphalia',
#  'Roswell-incident',
#  '229388',
#  'U-S-aid-to-China',
#  'octane-number',
#  'radio-energy',
#  'Sergey-Volkov',
#  'Howland-Island',
#  'Police-dogs',
#  'cannon-weapon',
#  '223',
#  'Electricity-in-agriculture',
#  'supercharger',
#  'London-bombings-of-2005',
#  '235653',
#  'photodiode',
#  'finger-four',
#  '353940',
#  ...]

# %%
def retrive(link, file_name):
    web_text = ""
    try:
        page = requests.get(link)
        soup = BeautifulSoup(page.content, "html.parser")
        # getting all the paragraphs
        for para in soup.find_all("p"):
            web_text = web_text + para.get_text() + "\n"
        # print(para.get_text())
        with open(f'data/britanica_texts/{file_name}.txt', 'w') as f:
            f.write(web_text)
#             print(f'save file in name of {file_name}.txt')
        sleep(1.1)
    except:
        print("An exception occurred")
        sleep(30)

# %%
def retrive(link, file_name, dataset=''):
    web_text = ""
    try:
        page = requests.get(link)
        soup = BeautifulSoup(page.content, "html.parser")
        # getting all the paragraphs
        for para in soup.find_all("p"):
            web_text = web_text + para.get_text() + "\n"
        # print(para.get_text())
        with open(f'data/britanica_texts/{dataset}{file_name}.txt', 'w') as f:
            f.write(web_text)
#             print(f'save file in name of {file_name}.txt')
        sleep(1.1)
    except:
        print("An exception occurred")
        sleep(30)

# %%
scarped_words = []
len(scarped_words)
# Out:
# 0

# %%
dataset = 'aviation/'
for el in data:
    if el not in scarped_words:
        print(f"***** fetch {len(data[el])} articles about {el} *******")
        for l in data[el]:
            file_names = [f.rsplit('/', 1)[1] for f in glob.glob(f"data/britanica_texts/{dataset}*.txt")]
            l_split, r_split = l.rsplit('/', 1)
            if r_split == '':
                file_name = l_split.rsplit('/', 1)[1]
            else:
                file_name = l.rsplit('/', 1)[1]
            if file_name + '.txt' not in file_names:
                print(f"retrive {l, file_name}")
                retrive(l, file_name, dataset=dataset)
    #         else:
    #             print(f"already searched for {file_name}")
        scarped_words.append(el)
        remain_words = list(set(filtred_words) - set(scarped_words))
        print(f'____________________________________ remain: {len(remain_words)} _________________________________')
# Out:
# ***** fetch 100 articles about kind *******
# ____________________________________ remain: 699 _________________________________
# ***** fetch 90 articles about skeletal frame *******
# ____________________________________ remain: 698 _________________________________
# ***** fetch 2 articles about dermopteran *******
# ____________________________________ remain: 697 _________________________________
# ***** fetch 100 articles about deck *******
# ____________________________________ remain: 696 _________________________________
# ***** fetch 100 articles about destroyer *******
# ____________________________________ remain: 695 _________________________________
# ***** fetch 65 articles about procurement *******
# ____________________________________ remain: 694 _________________________________
# ***** fetch 100 articles about combustion chamber *******
# ____________________________________ remain: 693 _________________________________
# ***** fetch 100 articles about equipment *******
# ____________________________________ remain: 692 _________________________________
# ***** fetch 100 articles about land plane *******
# ____________________________________ remain: 691 _________________________________
# ***** fetch 100 articles about fare *******
# ____________________________________ remain: 690 _________________________________
# ***** fetch 100 articles about corp *******
# ____________________________________ remain: 689 _________________________________
# ***** fetch 100 articles about replacement *******
# ____________________________________ remain: 688 _________________________________
# ***** fetch 100 articles about function *******
# ____________________________________ remain: 687 _________________________________
# ***** fetch 100 articles about position *******
# ____________________________________ remain: 686 _________________________________
# ***** fetch 100 articles about weapon *******
# ____________________________________ remain: 685 _________________________________
# ***** fetch 7 articles about vfr *******
# ____________________________________ remain: 684 _________________________________
# ***** fetch 100 articles about personnel *******
# ____________________________________ remain: 683 _________________________________
# ***** fetch 100 articles about mail *******
# ____________________________________ remain: 682 _________________________________
# ***** fetch 100 articles about air transports of heads of state and government *******
# ____________________________________ remain: 681 _________________________________
# ***** fetch 100 articles about way *******
# ____________________________________ remain: 680 _________________________________
# ***** fetch 100 articles about airman *******
# ____________________________________ remain: 679 _________________________________
# ***** fetch 100 articles about role *******
# ____________________________________ remain: 678 _________________________________
# ***** fetch 72 articles about scramjet *******
# ____________________________________ remain: 677 _________________________________
# ***** fetch 100 articles about aileron *******
# ____________________________________ remain: 676 _________________________________
# ***** fetch 29 articles about gadfly *******
# ____________________________________ remain: 675 _________________________________
# ***** fetch 55 articles about destabilization *******
# ____________________________________ remain: 674 _________________________________
# ***** fetch 100 articles about israel *******
# ____________________________________ remain: 673 _________________________________
# ***** fetch 100 articles about lighter-than-air *******
# ____________________________________ remain: 672 _________________________________
# ***** fetch 9 articles about dihedral *******
# ____________________________________ remain: 671 _________________________________
# ***** fetch 100 articles about pursuit *******
# ____________________________________ remain: 670 _________________________________
# ***** fetch 100 articles about hunter *******
# ____________________________________ remain: 669 _________________________________
# ***** fetch 100 articles about shuttle *******
# ____________________________________ remain: 668 _________________________________
# ***** fetch 100 articles about weight *******
# ____________________________________ remain: 667 _________________________________
# ***** fetch 2 articles about warble fly *******
# ____________________________________ remain: 666 _________________________________
# ***** fetch 100 articles about sale *******
# ____________________________________ remain: 665 _________________________________
# ***** fetch 100 articles about cruise missile *******
# ____________________________________ remain: 664 _________________________________
# ***** fetch 100 articles about wright brothers *******
# ____________________________________ remain: 663 _________________________________
# ***** fetch 13 articles about hydroaeroplane *******
# ____________________________________ remain: 662 _________________________________
# ***** fetch 100 articles about turbofan *******
# ____________________________________ remain: 661 _________________________________
# ***** fetch 100 articles about hardware *******
# ____________________________________ remain: 660 _________________________________
# ***** fetch 0 articles about cyclogyro *******
# ____________________________________ remain: 659 _________________________________
# ***** fetch 100 articles about skeleton *******
# ____________________________________ remain: 658 _________________________________
# ***** fetch 100 articles about association *******
# ____________________________________ remain: 657 _________________________________
# ***** fetch 100 articles about scale model *******
# ____________________________________ remain: 656 _________________________________
# ***** fetch 100 articles about airframe *******
# ____________________________________ remain: 655 _________________________________
# ***** fetch 100 articles about cockpit *******
# ____________________________________ remain: 654 _________________________________
# ***** fetch 100 articles about vintage *******
# ____________________________________ remain: 653 _________________________________
# ***** fetch 100 articles about land on runway *******
# ____________________________________ remain: 652 _________________________________
# ***** fetch 75 articles about 737 *******
# ____________________________________ remain: 651 _________________________________
# ***** fetch 26 articles about convertiplane *******
# ____________________________________ remain: 650 _________________________________
# ***** fetch 100 articles about unmanned *******
# ____________________________________ remain: 649 _________________________________
# ***** fetch 95 articles about v/stol *******
# ____________________________________ remain: 648 _________________________________
# ***** fetch 100 articles about supply *******
# ____________________________________ remain: 647 _________________________________
# ***** fetch 100 articles about industry *******
# ____________________________________ remain: 646 _________________________________
# ***** fetch 100 articles about fly *******
# ____________________________________ remain: 645 _________________________________
# ***** fetch 100 articles about f-16 *******
# ____________________________________ remain: 644 _________________________________
# ***** fetch 100 articles about strike *******
# ____________________________________ remain: 643 _________________________________
# ***** fetch 100 articles about radar *******
# ____________________________________ remain: 642 _________________________________
# ***** fetch 100 articles about commercial aviation *******
# ____________________________________ remain: 641 _________________________________
# ***** fetch 100 articles about bombardment *******
# ____________________________________ remain: 640 _________________________________
# ***** fetch 80 articles about fly buttress *******
# ____________________________________ remain: 639 _________________________________
# ***** fetch 100 articles about submarine *******
# ____________________________________ remain: 638 _________________________________
# ***** fetch 0 articles about brachypterous *******
# ____________________________________ remain: 637 _________________________________
# ***** fetch 100 articles about respect *******
# ____________________________________ remain: 636 _________________________________
# ***** fetch 100 articles about airport *******
# ____________________________________ remain: 635 _________________________________
# ***** fetch 3 articles about aviatrix *******
# ____________________________________ remain: 634 _________________________________
# ***** fetch 100 articles about human-powered flight *******
# ____________________________________ remain: 633 _________________________________
# ***** fetch 100 articles about driftage *******
# ____________________________________ remain: 632 _________________________________
# ***** fetch 23 articles about copter *******
# ____________________________________ remain: 631 _________________________________
# ***** fetch 100 articles about coast *******
# ____________________________________ remain: 630 _________________________________
# ***** fetch 100 articles about altitude *******
# ____________________________________ remain: 629 _________________________________
# ***** fetch 100 articles about private aviation *******
# ____________________________________ remain: 628 _________________________________
# ***** fetch 3 articles about elevon *******
# ____________________________________ remain: 627 _________________________________
# ***** fetch 100 articles about lockheed *******
# ____________________________________ remain: 626 _________________________________
# ***** fetch 65 articles about cessna *******
# ____________________________________ remain: 625 _________________________________
# ***** fetch 50 articles about wingy *******
# ____________________________________ remain: 624 _________________________________
# ***** fetch 100 articles about figure *******
# ____________________________________ remain: 623 _________________________________
# ***** fetch 100 articles about angles of rotation *******
# ____________________________________ remain: 622 _________________________________
# ***** fetch 100 articles about shore *******
# ____________________________________ remain: 621 _________________________________
# ***** fetch 100 articles about operation *******
# ____________________________________ remain: 620 _________________________________
# ***** fetch 47 articles about tiltrotor *******
# ____________________________________ remain: 619 _________________________________
# ***** fetch 100 articles about spray *******
# ____________________________________ remain: 618 _________________________________
# ***** fetch 100 articles about air show *******
# ____________________________________ remain: 617 _________________________________
# ***** fetch 100 articles about operator *******
# ____________________________________ remain: 616 _________________________________
# ***** fetch 19 articles about propfan *******
# ____________________________________ remain: 615 _________________________________
# ***** fetch 100 articles about carry *******
# ____________________________________ remain: 614 _________________________________
# ***** fetch 100 articles about system *******
# ____________________________________ remain: 613 _________________________________
# ***** fetch 100 articles about motor *******
# ____________________________________ remain: 612 _________________________________
# ***** fetch 100 articles about camera *******
# ____________________________________ remain: 611 _________________________________
# ***** fetch 52 articles about chopper *******
# ____________________________________ remain: 610 _________________________________
# ***** fetch 100 articles about co *******
# ____________________________________ remain: 609 _________________________________
# ***** fetch 100 articles about dry fly *******
# ____________________________________ remain: 608 _________________________________
# ***** fetch 100 articles about design process *******
# ____________________________________ remain: 607 _________________________________
# ***** fetch 100 articles about radio *******
# ____________________________________ remain: 606 _________________________________
# ***** fetch 100 articles about side *******
# ____________________________________ remain: 605 _________________________________
# ***** fetch 0 articles about coleopter *******
# ____________________________________ remain: 604 _________________________________
# ***** fetch 0 articles about pratt & whitney j58 *******
# ____________________________________ remain: 603 _________________________________
# ***** fetch 0 articles about cleg *******
# ____________________________________ remain: 602 _________________________________
# ***** fetch 100 articles about flytrap *******
# ____________________________________ remain: 601 _________________________________
# ***** fetch 100 articles about automobile *******
# ____________________________________ remain: 600 _________________________________
# ***** fetch 100 articles about company *******
# ____________________________________ remain: 599 _________________________________
# ***** fetch 100 articles about spotter *******
# ____________________________________ remain: 598 _________________________________
# ***** fetch 0 articles about kytoon *******
# ____________________________________ remain: 597 _________________________________
# ***** fetch 100 articles about flight dynamics *******
# ____________________________________ remain: 596 _________________________________
# ***** fetch 100 articles about piston engine *******
# ____________________________________ remain: 595 _________________________________
# ***** fetch 100 articles about electric *******
# ____________________________________ remain: 594 _________________________________
# ***** fetch 100 articles about jet *******
# ____________________________________ remain: 593 _________________________________
# ***** fetch 26 articles about pusher configuration *******
# ____________________________________ remain: 592 _________________________________
# ***** fetch 100 articles about environmental impact of aviation *******
# ____________________________________ remain: 591 _________________________________
# ***** fetch 100 articles about aircrew *******
# ____________________________________ remain: 590 _________________________________
# ***** fetch 73 articles about rotorcraft *******
# ____________________________________ remain: 589 _________________________________
# ***** fetch 100 articles about surplus *******
# ____________________________________ remain: 588 _________________________________
# ***** fetch 100 articles about lifting body *******
# ____________________________________ remain: 587 _________________________________
# ***** fetch 100 articles about touch down *******
# ____________________________________ remain: 586 _________________________________
# ***** fetch 51 articles about vtol *******
# ____________________________________ remain: 585 _________________________________
# ***** fetch 100 articles about air terminal *******
# ____________________________________ remain: 584 _________________________________
# ***** fetch 100 articles about military *******
# ____________________________________ remain: 583 _________________________________
# ***** fetch 100 articles about wind *******
# ____________________________________ remain: 582 _________________________________
# ***** fetch 100 articles about damage *******
# ____________________________________ remain: 581 _________________________________
# ***** fetch 3 articles about alula *******
# ____________________________________ remain: 580 _________________________________
# ***** fetch 6 articles about fisherman's lure *******
# ____________________________________ remain: 579 _________________________________
# ***** fetch 100 articles about wing *******
# ____________________________________ remain: 578 _________________________________
# ***** fetch 100 articles about powered lift *******
# ____________________________________ remain: 577 _________________________________
# ***** fetch 100 articles about load factor *******
# ____________________________________ remain: 576 _________________________________
# ***** fetch 100 articles about period *******
# ____________________________________ remain: 575 _________________________________
# ***** fetch 100 articles about aerodynamics *******
# ____________________________________ remain: 574 _________________________________
# ***** fetch 100 articles about communication system *******
# ____________________________________ remain: 573 _________________________________
# ***** fetch 100 articles about fact *******
# ____________________________________ remain: 572 _________________________________
# ***** fetch 100 articles about drag *******
# ____________________________________ remain: 571 _________________________________
# ***** fetch 100 articles about atlantic ocean *******
# ____________________________________ remain: 570 _________________________________
# ***** fetch 0 articles about syrphian *******
# ____________________________________ remain: 569 _________________________________
# ***** fetch 100 articles about photo *******
# ____________________________________ remain: 568 _________________________________
# ***** fetch 100 articles about structure *******
# ____________________________________ remain: 567 _________________________________
# ***** fetch 100 articles about patrol *******
# ____________________________________ remain: 566 _________________________________
# ***** fetch 100 articles about observation *******
# ____________________________________ remain: 565 _________________________________
# ***** fetch 53 articles about autogiro *******
# ____________________________________ remain: 564 _________________________________
# ***** fetch 4 articles about cursorily *******
# ____________________________________ remain: 563 _________________________________
# ***** fetch 65 articles about aerodynamic center *******
# ____________________________________ remain: 562 _________________________________
# ***** fetch 100 articles about hughes *******
# ____________________________________ remain: 561 _________________________________
# ***** fetch 5 articles about bogey *******
# ____________________________________ remain: 560 _________________________________
# ***** fetch 36 articles about fairchild *******
# ____________________________________ remain: 559 _________________________________
# ***** fetch 7 articles about mainplane *******
# ____________________________________ remain: 558 _________________________________
# ***** fetch 85 articles about liaison *******
# ____________________________________ remain: 557 _________________________________
# ***** fetch 100 articles about axis *******
# ____________________________________ remain: 556 _________________________________
# ***** fetch 100 articles about production *******
# ____________________________________ remain: 555 _________________________________
# ***** fetch 6 articles about sandfly *******
# ____________________________________ remain: 554 _________________________________
# ***** fetch 100 articles about fig *******
# ____________________________________ remain: 553 _________________________________
# ***** fetch 100 articles about air lane *******
# ____________________________________ remain: 552 _________________________________
# ***** fetch 19 articles about luggage carrier *******
# ____________________________________ remain: 551 _________________________________
# ***** fetch 100 articles about operational *******
# ____________________________________ remain: 550 _________________________________
# ***** fetch 37 articles about paraglider *******
# ____________________________________ remain: 549 _________________________________
# ***** fetch 100 articles about series *******
# ____________________________________ remain: 548 _________________________________
# ***** fetch 17 articles about midflight *******
# ____________________________________ remain: 547 _________________________________
# ***** fetch 100 articles about establishment *******
# ____________________________________ remain: 546 _________________________________
# ***** fetch 100 articles about characteristic *******
# ____________________________________ remain: 545 _________________________________
# ***** fetch 100 articles about deployed *******
# ____________________________________ remain: 544 _________________________________
# ***** fetch 100 articles about flier *******
# ____________________________________ remain: 543 _________________________________
# ***** fetch 100 articles about fire *******
# ____________________________________ remain: 542 _________________________________
# ***** fetch 100 articles about accident *******
# ____________________________________ remain: 541 _________________________________
# ***** fetch 100 articles about design *******
# ____________________________________ remain: 540 _________________________________
# ***** fetch 100 articles about ton *******
# ____________________________________ remain: 539 _________________________________
# ***** fetch 100 articles about knowledge *******
# ____________________________________ remain: 538 _________________________________
# ***** fetch 4 articles about downwash *******
# ____________________________________ remain: 537 _________________________________
# ***** fetch 100 articles about navy *******
# ____________________________________ remain: 536 _________________________________
# ***** fetch 100 articles about propeller *******
# ____________________________________ remain: 535 _________________________________
# ***** fetch 44 articles about ducted fan *******
# ____________________________________ remain: 534 _________________________________
# ***** fetch 100 articles about stealth *******
# ____________________________________ remain: 533 _________________________________
# ***** fetch 100 articles about gunner *******
# ____________________________________ remain: 532 _________________________________
# ***** fetch 0 articles about avolation *******
# ____________________________________ remain: 531 _________________________________
# ***** fetch 2 articles about deplane *******
# ____________________________________ remain: 530 _________________________________
# ***** fetch 100 articles about suicide *******
# ____________________________________ remain: 529 _________________________________
# ***** fetch 100 articles about buoyancy *******
# ____________________________________ remain: 528 _________________________________
# ***** fetch 2 articles about underframe *******
# ____________________________________ remain: 527 _________________________________
# ***** fetch 100 articles about sweptwing *******
# ____________________________________ remain: 526 _________________________________
# ***** fetch 100 articles about metal *******
# ____________________________________ remain: 525 _________________________________
# ***** fetch 100 articles about building *******
# ____________________________________ remain: 524 _________________________________
# ***** fetch 100 articles about board *******
# ____________________________________ remain: 523 _________________________________
# ***** fetch 100 articles about state *******
# ____________________________________ remain: 522 _________________________________
# ***** fetch 48 articles about autopilot *******
# ____________________________________ remain: 521 _________________________________
# ***** fetch 100 articles about air travel *******
# ____________________________________ remain: 520 _________________________________
# ***** fetch 100 articles about flyingly *******
# ____________________________________ remain: 519 _________________________________
# ***** fetch 100 articles about rig *******
# ____________________________________ remain: 518 _________________________________
# ***** fetch 100 articles about line *******
# ____________________________________ remain: 517 _________________________________
# ***** fetch 100 articles about flight bag *******
# ____________________________________ remain: 516 _________________________________
# ***** fetch 100 articles about disposal *******
# ____________________________________ remain: 515 _________________________________
# ***** fetch 100 articles about hang glide *******
# ____________________________________ remain: 514 _________________________________
# ***** fetch 100 articles about reconnaissance plane *******
# ____________________________________ remain: 513 _________________________________
# ***** fetch 100 articles about air to air *******
# ____________________________________ remain: 512 _________________________________
# ***** fetch 100 articles about airfare *******
# ____________________________________ remain: 511 _________________________________
# ***** fetch 100 articles about internal combustion engine *******
# ____________________________________ remain: 510 _________________________________
# ***** fetch 2 articles about gallfly *******
# ____________________________________ remain: 509 _________________________________
# ***** fetch 100 articles about grumman *******
# ____________________________________ remain: 508 _________________________________
# ***** fetch 100 articles about airforce *******
# ____________________________________ remain: 507 _________________________________
# ***** fetch 100 articles about cabin *******
# ____________________________________ remain: 506 _________________________________
# ***** fetch 100 articles about biplane *******
# ____________________________________ remain: 505 _________________________________
# ***** fetch 17 articles about horsefly *******
# ____________________________________ remain: 504 _________________________________
# ***** fetch 100 articles about george cayley *******
# ____________________________________ remain: 503 _________________________________
# ***** fetch 100 articles about shell *******
# ____________________________________ remain: 502 _________________________________
# ***** fetch 100 articles about flight *******
# ____________________________________ remain: 501 _________________________________
# ***** fetch 100 articles about nato *******
# ____________________________________ remain: 500 _________________________________
# ***** fetch 57 articles about aerodrome *******
# ____________________________________ remain: 499 _________________________________
# ***** fetch 100 articles about limit *******
# ____________________________________ remain: 498 _________________________________
# ***** fetch 100 articles about event *******
# ____________________________________ remain: 497 _________________________________
# ***** fetch 99 articles about related words continue after advertisement *******
# ____________________________________ remain: 496 _________________________________
# ***** fetch 16 articles about empennage *******
# ____________________________________ remain: 495 _________________________________
# ***** fetch 100 articles about rescue *******
# ____________________________________ remain: 494 _________________________________
# ***** fetch 100 articles about application *******
# ____________________________________ remain: 493 _________________________________
# ***** fetch 100 articles about safety *******
# ____________________________________ remain: 492 _________________________________
# ***** fetch 25 articles about stabilisation *******
# ____________________________________ remain: 491 _________________________________
# ***** fetch 100 articles about c-130 *******
# ____________________________________ remain: 490 _________________________________
# ***** fetch 100 articles about percent *******
# ____________________________________ remain: 489 _________________________________
# ***** fetch 2 articles about subimago *******
# ____________________________________ remain: 488 _________________________________
# ***** fetch 0 articles about aerophobic *******
# ____________________________________ remain: 487 _________________________________
# ***** fetch 100 articles about tail *******
# ____________________________________ remain: 486 _________________________________
# ***** fetch 100 articles about crash landing *******
# ____________________________________ remain: 485 _________________________________
# ***** fetch 0 articles about flysheet *******
# ____________________________________ remain: 484 _________________________________
# ***** fetch 100 articles about jet engine *******
# ____________________________________ remain: 483 _________________________________
# ***** fetch 100 articles about flown *******
# ____________________________________ remain: 482 _________________________________
# ***** fetch 29 articles about rotor kite *******
# ____________________________________ remain: 481 _________________________________
# ***** fetch 100 articles about variety *******
# ____________________________________ remain: 480 _________________________________
# ***** fetch 0 articles about gyrodyne *******
# ____________________________________ remain: 479 _________________________________
# ***** fetch 100 articles about appliance *******
# ____________________________________ remain: 478 _________________________________
# ***** fetch 100 articles about heavier-than-air *******
# ____________________________________ remain: 477 _________________________________
# ***** fetch 100 articles about purpose *******
# ____________________________________ remain: 476 _________________________________
# ***** fetch 93 articles about homebuilt *******
# ____________________________________ remain: 475 _________________________________
# ***** fetch 100 articles about airplane pilot *******
# ____________________________________ remain: 474 _________________________________
# ***** fetch 100 articles about defense *******
# ____________________________________ remain: 473 _________________________________
# ***** fetch 51 articles about sailplane *******
# ____________________________________ remain: 472 _________________________________
# ***** fetch 5 articles about outwing *******
# ____________________________________ remain: 471 _________________________________
# ***** fetch 100 articles about helicopter *******
# ____________________________________ remain: 470 _________________________________
# ***** fetch 100 articles about sky *******
# ____________________________________ remain: 469 _________________________________
# ***** fetch 43 articles about sweptback *******
# ____________________________________ remain: 468 _________________________________
# ***** fetch 100 articles about scale *******
# ____________________________________ remain: 467 _________________________________
# ***** fetch 100 articles about plant *******
# ____________________________________ remain: 466 _________________________________
# ***** fetch 100 articles about body *******
# ____________________________________ remain: 465 _________________________________
# ***** fetch 100 articles about mm *******
# ____________________________________ remain: 464 _________________________________
# ***** fetch 63 articles about non-rigid airship *******
# ____________________________________ remain: 463 _________________________________
# ***** fetch 100 articles about future *******
# ____________________________________ remain: 462 _________________________________
# ***** fetch 100 articles about time *******
# ____________________________________ remain: 461 _________________________________
# ***** fetch 100 articles about path *******
# ____________________________________ remain: 460 _________________________________
# ***** fetch 100 articles about part *******
# ____________________________________ remain: 459 _________________________________
# ***** fetch 100 articles about vessel *******
# ____________________________________ remain: 458 _________________________________
# ***** fetch 100 articles about martin *******
# ____________________________________ remain: 457 _________________________________
# ***** fetch 100 articles about requirement *******
# ____________________________________ remain: 456 _________________________________
# ***** fetch 100 articles about air safety *******
# ____________________________________ remain: 455 _________________________________
# ***** fetch 100 articles about aboard *******
# ____________________________________ remain: 454 _________________________________
# ***** fetch 100 articles about flight control surfaces *******
# ____________________________________ remain: 453 _________________________________
# ***** fetch 100 articles about flying wing *******
# ____________________________________ remain: 452 _________________________________
# ***** fetch 100 articles about separation *******
# ____________________________________ remain: 451 _________________________________
# ***** fetch 60 articles about pitching moment *******
# ____________________________________ remain: 450 _________________________________
# ***** fetch 100 articles about aero *******
# ____________________________________ remain: 449 _________________________________
# ***** fetch 100 articles about manufacturer *******
# ____________________________________ remain: 448 _________________________________
# ***** fetch 100 articles about component *******
# ____________________________________ remain: 447 _________________________________
# ***** fetch 0 articles about ahool *******
# ____________________________________ remain: 446 _________________________________
# ***** fetch 1 articles about leeway *******
# ____________________________________ remain: 445 _________________________________
# ***** fetch 100 articles about northrop *******
# ____________________________________ remain: 444 _________________________________
# ***** fetch 100 articles about flight deck *******
# ____________________________________ remain: 443 _________________________________
# ***** fetch 100 articles about aerial *******
# ____________________________________ remain: 442 _________________________________
# ***** fetch 100 articles about bell *******
# ____________________________________ remain: 441 _________________________________
# ***** fetch 100 articles about tip jet *******
# ____________________________________ remain: 440 _________________________________
# ***** fetch 100 articles about manufacture *******
# ____________________________________ remain: 439 _________________________________
# ***** fetch 100 articles about prototype *******
# ____________________________________ remain: 438 _________________________________
# ***** fetch 100 articles about aerospace *******
# ____________________________________ remain: 437 _________________________________
# ***** fetch 95 articles about flyrod *******
# ____________________________________ remain: 436 _________________________________
# ***** fetch 100 articles about fly ball *******
# ____________________________________ remain: 435 _________________________________
# ***** fetch 100 articles about douglas *******
# ____________________________________ remain: 434 _________________________________
# ***** fetch 100 articles about seat *******
# ____________________________________ remain: 433 _________________________________
# ***** fetch 100 articles about twin *******
# ____________________________________ remain: 432 _________________________________
# ***** fetch 29 articles about airbrake *******
# ____________________________________ remain: 431 _________________________________
# ***** fetch 46 articles about embarkation *******
# ____________________________________ remain: 430 _________________________________
# ***** fetch 100 articles about glide *******
# ____________________________________ remain: 429 _________________________________
# ***** fetch 100 articles about manufacturing *******
# ____________________________________ remain: 428 _________________________________
# ***** fetch 100 articles about craft *******
# ____________________________________ remain: 427 _________________________________
# ***** fetch 100 articles about fixed-wing *******
# ____________________________________ remain: 426 _________________________________
# ***** fetch 100 articles about velocity *******
# ____________________________________ remain: 425 _________________________________
# ***** fetch 100 articles about surveillance *******
# ____________________________________ remain: 424 _________________________________
# ***** fetch 100 articles about area *******
# ____________________________________ remain: 423 _________________________________
# ***** fetch 100 articles about turbine *******
# ____________________________________ remain: 422 _________________________________
# ***** fetch 100 articles about center of mass *******
# ____________________________________ remain: 421 _________________________________
# ***** fetch 100 articles about attack *******
# ____________________________________ remain: 420 _________________________________
# ***** fetch 100 articles about pirate *******
# ____________________________________ remain: 419 _________________________________
# ***** fetch 0 articles about flypost *******
# ____________________________________ remain: 418 _________________________________
# ***** fetch 100 articles about wing configuration *******
# ____________________________________ remain: 417 _________________________________
# ***** fetch 100 articles about cruiser *******
# ____________________________________ remain: 416 _________________________________
# ***** fetch 0 articles about vortilon *******
# ____________________________________ remain: 415 _________________________________
# ***** fetch 5 articles about tailsitter *******
# ____________________________________ remain: 414 _________________________________
# ***** fetch 100 articles about takeoff *******
# ____________________________________ remain: 413 _________________________________
# ***** fetch 100 articles about battery *******
# ____________________________________ remain: 412 _________________________________
# ***** fetch 100 articles about airway *******
# ____________________________________ remain: 411 _________________________________
# ***** fetch 100 articles about interceptor *******
# ____________________________________ remain: 410 _________________________________
# ***** fetch 48 articles about frederick handley page *******
# ____________________________________ remain: 409 _________________________________
# ***** fetch 100 articles about heavier-than-air craft *******
# ____________________________________ remain: 408 _________________________________
# ***** fetch 78 articles about stol *******
# ____________________________________ remain: 407 _________________________________
# ***** fetch 100 articles about turboprop *******
# ____________________________________ remain: 406 _________________________________
# ***** fetch 0 articles about unflighted *******
# ____________________________________ remain: 405 _________________________________
# ***** fetch 9 articles about autogyro *******
# ____________________________________ remain: 404 _________________________________
# ***** fetch 76 articles about gadget *******
# ____________________________________ remain: 403 _________________________________
# ***** fetch 100 articles about wartime *******
# ____________________________________ remain: 402 _________________________________
# ***** fetch 100 articles about fighter *******
# ____________________________________ remain: 401 _________________________________
# ***** fetch 100 articles about enterprise *******
# ____________________________________ remain: 400 _________________________________
# ***** fetch 9 articles about deice *******
# ____________________________________ remain: 399 _________________________________
# ***** fetch 0 articles about papilionaceous *******
# ____________________________________ remain: 398 _________________________________
# ***** fetch 100 articles about charter *******
# ____________________________________ remain: 397 _________________________________
# ***** fetch 100 articles about armored *******
# ____________________________________ remain: 396 _________________________________
# ***** fetch 100 articles about direct flight *******
# ____________________________________ remain: 395 _________________________________
# ***** fetch 100 articles about operate *******
# ____________________________________ remain: 394 _________________________________
# ***** fetch 100 articles about propulsion *******
# ____________________________________ remain: 393 _________________________________
# ***** fetch 100 articles about corporation *******
# ____________________________________ remain: 392 _________________________________
# ***** fetch 100 articles about begin *******
# ____________________________________ remain: 391 _________________________________
# ***** fetch 100 articles about airfoil *******
# ____________________________________ remain: 390 _________________________________
# ***** fetch 100 articles about airspeed *******
# ____________________________________ remain: 389 _________________________________
# ***** fetch 0 articles about batwing *******
# ____________________________________ remain: 388 _________________________________
# ***** fetch 100 articles about command *******
# ____________________________________ remain: 387 _________________________________
# ***** fetch 20 articles about wingmanship *******
# ____________________________________ remain: 386 _________________________________
# ***** fetch 0 articles about aeropause *******
# ____________________________________ remain: 385 _________________________________
# ***** fetch 100 articles about tract *******
# ____________________________________ remain: 384 _________________________________
# ***** fetch 100 articles about supersonic *******
# ____________________________________ remain: 383 _________________________________
# ***** fetch 100 articles about lift *******
# ____________________________________ remain: 382 _________________________________
# ***** fetch 0 articles about bobfly *******
# ____________________________________ remain: 381 _________________________________
# ***** fetch 100 articles about worker *******
# ____________________________________ remain: 380 _________________________________
# ***** fetch 100 articles about airlift *******
# ____________________________________ remain: 379 _________________________________
# ***** fetch 16 articles about airscrew *******
# ____________________________________ remain: 378 _________________________________
# ***** fetch 100 articles about mechanic *******
# ____________________________________ remain: 377 _________________________________
# ***** fetch 67 articles about piper *******
# ____________________________________ remain: 376 _________________________________
# ***** fetch 100 articles about heavy than air *******
# ____________________________________ remain: 375 _________________________________
# ***** fetch 100 articles about gun *******
# ____________________________________ remain: 374 _________________________________
# ***** fetch 100 articles about mcdonnell *******
# ____________________________________ remain: 373 _________________________________
# ***** fetch 100 articles about bombing *******
# ____________________________________ remain: 372 _________________________________
# ***** fetch 10 articles about sawfly *******
# ____________________________________ remain: 371 _________________________________
# ***** fetch 0 articles about befly *******
# ____________________________________ remain: 370 _________________________________
# ***** fetch 100 articles about size *******
# ____________________________________ remain: 369 _________________________________
# ***** fetch 51 articles about tailless *******
# ____________________________________ remain: 368 _________________________________
# ***** fetch 100 articles about warn *******
# ____________________________________ remain: 367 _________________________________
# ***** fetch 100 articles about amphibious *******
# ____________________________________ remain: 366 _________________________________
# ***** fetch 100 articles about squadron *******
# ____________________________________ remain: 365 _________________________________
# ***** fetch 100 articles about control system *******
# ____________________________________ remain: 364 _________________________________
# ***** fetch 100 articles about military glider *******
# ____________________________________ remain: 363 _________________________________
# ***** fetch 100 articles about passenger *******
# ____________________________________ remain: 362 _________________________________
# ***** fetch 83 articles about shipboard *******
# ____________________________________ remain: 361 _________________________________
# ***** fetch 100 articles about flight control system *******
# ____________________________________ remain: 360 _________________________________
# ***** fetch 24 articles about yaw angle *******
# ____________________________________ remain: 359 _________________________________
# ***** fetch 100 articles about operating *******
# ____________________________________ remain: 358 _________________________________
# ***** fetch 100 articles about arm *******
# ____________________________________ remain: 357 _________________________________
# ***** fetch 100 articles about enemy's *******
# ____________________________________ remain: 356 _________________________________
# ***** fetch 100 articles about ground *******
# ____________________________________ remain: 355 _________________________________
# ***** fetch 100 articles about no fly on *******
# ____________________________________ remain: 354 _________________________________
# ***** fetch 100 articles about navigation *******
# ____________________________________ remain: 353 _________________________________
# ***** fetch 100 articles about hot air balloon *******
# ____________________________________ remain: 352 _________________________________
# ***** fetch 10 articles about gyroplane *******
# ____________________________________ remain: 351 _________________________________
# ***** fetch 100 articles about ala *******
# ____________________________________ remain: 350 _________________________________
# ***** fetch 32 articles about triplane *******
# ____________________________________ remain: 349 _________________________________
# ***** fetch 100 articles about civil aviation *******
# ____________________________________ remain: 348 _________________________________
# ***** fetch 100 articles about instrumentation *******
# ____________________________________ remain: 347 _________________________________
# ***** fetch 100 articles about location *******
# ____________________________________ remain: 346 _________________________________
# ***** fetch 100 articles about fly airplane *******
# ____________________________________ remain: 345 _________________________________
# ***** fetch 100 articles about bay *******
# ____________________________________ remain: 344 _________________________________
# ***** fetch 100 articles about cargo *******
# ____________________________________ remain: 343 _________________________________
# ***** fetch 100 articles about designer *******
# ____________________________________ remain: 342 _________________________________
# ***** fetch 100 articles about work *******
# ____________________________________ remain: 341 _________________________________
# ***** fetch 100 articles about jurisdiction *******
# ____________________________________ remain: 340 _________________________________
# ***** fetch 5 articles about asw *******
# ____________________________________ remain: 339 _________________________________
# ***** fetch 2 articles about dimout *******
# ____________________________________ remain: 338 _________________________________
# ***** fetch 100 articles about turbojet *******
# ____________________________________ remain: 337 _________________________________
# ***** fetch 100 articles about cruise *******
# ____________________________________ remain: 336 _________________________________
# ***** fetch 100 articles about fleet *******
# ____________________________________ remain: 335 _________________________________
# ***** fetch 55 articles about flyover *******
# ...
# ***** fetch 100 articles about space *******
# ____________________________________ remain: 122 _________________________________
# ***** fetch 100 articles about havilland *******
# ____________________________________ remain: 121 _________________________________
# ***** fetch 60 articles about pulse jet engine *******
# ____________________________________ remain: 120 _________________________________
# ***** fetch 100 articles about general aviation *******
# ____________________________________ remain: 119 _________________________________
# ***** fetch 100 articles about skin *******
# ____________________________________ remain: 118 _________________________________
# ***** fetch 98 articles about kite line *******
# ____________________________________ remain: 117 _________________________________
# ***** fetch 100 articles about ramjet *******
# ____________________________________ remain: 116 _________________________________
# ***** fetch 100 articles about range *******
# ____________________________________ remain: 115 _________________________________
# ***** fetch 13 articles about lacewing *******
# ____________________________________ remain: 114 _________________________________
# ***** fetch 100 articles about crashed *******
# ____________________________________ remain: 113 _________________________________
# ***** fetch 100 articles about parking *******
# ____________________________________ remain: 112 _________________________________
# ***** fetch 21 articles about dragonfly *******
# ____________________________________ remain: 111 _________________________________
# ***** fetch 100 articles about group *******
# ____________________________________ remain: 110 _________________________________
# ***** fetch 100 articles about tank *******
# ____________________________________ remain: 109 _________________________________
# ***** fetch 100 articles about target *******
# ____________________________________ remain: 108 _________________________________
# ***** fetch 100 articles about symmetry *******
# ____________________________________ remain: 107 _________________________________
# ***** fetch 100 articles about frame *******
# ____________________________________ remain: 106 _________________________________
# ***** fetch 8 articles about blowfly *******
# ____________________________________ remain: 105 _________________________________
# ***** fetch 100 articles about technology *******
# ____________________________________ remain: 104 _________________________________
# ***** fetch 68 articles about flesh fly *******
# ____________________________________ remain: 103 _________________________________
# ***** fetch 100 articles about introduction *******
# ____________________________________ remain: 102 _________________________________
# ***** fetch 19 articles about overflown *******
# ____________________________________ remain: 101 _________________________________
# ***** fetch 100 articles about phone *******
# ____________________________________ remain: 100 _________________________________
# ***** fetch 100 articles about program *******
# ____________________________________ remain: 99 _________________________________
# ***** fetch 100 articles about mission *******
# ____________________________________ remain: 98 _________________________________
# ***** fetch 100 articles about development *******
# ____________________________________ remain: 97 _________________________________
# ***** fetch 85 articles about spare *******
# ____________________________________ remain: 96 _________________________________
# ***** fetch 100 articles about pitch *******
# ____________________________________ remain: 95 _________________________________
# ***** fetch 100 articles about unmanned aerial vehicle *******
# ____________________________________ remain: 94 _________________________________
# ***** fetch 16 articles about kiteflying *******
# ____________________________________ remain: 93 _________________________________
# ***** fetch 100 articles about at airport *******
# ____________________________________ remain: 92 _________________________________
# ***** fetch 100 articles about seaplane *******
# ____________________________________ remain: 91 _________________________________
# ***** fetch 74 articles about avion *******
# ____________________________________ remain: 90 _________________________________
# ***** fetch 36 articles about harrier jump jet *******
# ____________________________________ remain: 89 _________________________________
# ***** fetch 100 articles about united *******
# ____________________________________ remain: 88 _________________________________
# ***** fetch 100 articles about form *******
# ____________________________________ remain: 87 _________________________________
# ***** fetch 25 articles about 747-400 *******
# ____________________________________ remain: 86 _________________________________
# ***** fetch 6 articles about volant *******
# ____________________________________ remain: 85 _________________________________
# ***** fetch 0 articles about helijet *******
# ____________________________________ remain: 84 _________________________________
# ***** fetch 100 articles about crash *******
# ____________________________________ remain: 83 _________________________________
# ***** fetch 27 articles about blackout *******
# ____________________________________ remain: 82 _________________________________
# ***** fetch 100 articles about carrier *******
# ____________________________________ remain: 81 _________________________________
# ***** fetch 28 articles about contra-rotating propellers *******
# ____________________________________ remain: 80 _________________________________
# ***** fetch 100 articles about research *******
# ____________________________________ remain: 79 _________________________________
# ***** fetch 100 articles about aeronautic *******
# ____________________________________ remain: 78 _________________________________
# ***** fetch 100 articles about airline *******
# ____________________________________ remain: 77 _________________________________
# ***** fetch 0 articles about mothwing *******
# ____________________________________ remain: 76 _________________________________
# ***** fetch 100 articles about f-15 *******
# ____________________________________ remain: 75 _________________________________
# ***** fetch 100 articles about noise *******
# ____________________________________ remain: 74 _________________________________
# ***** fetch 100 articles about assembly *******
# ____________________________________ remain: 73 _________________________________
# ***** fetch 100 articles about warfare *******
# ____________________________________ remain: 72 _________________________________
# ***** fetch 100 articles about army *******
# ____________________________________ remain: 71 _________________________________
# ***** fetch 100 articles about jetliner *******
# ____________________________________ remain: 70 _________________________________
# ***** fetch 100 articles about attitude *******
# ____________________________________ remain: 69 _________________________________
# ***** fetch 100 articles about airliner *******
# ____________________________________ remain: 68 _________________________________
# ***** fetch 18 articles about contrail *******
# ____________________________________ remain: 67 _________________________________
# ***** fetch 4 articles about superjet *******
# ____________________________________ remain: 66 _________________________________
# ***** fetch 100 articles about power *******
# ____________________________________ remain: 65 _________________________________
# ***** fetch 100 articles about construction *******
# ____________________________________ remain: 64 _________________________________
# ***** fetch 100 articles about u *******
# ____________________________________ remain: 63 _________________________________
# ***** fetch 19 articles about flypast *******
# ____________________________________ remain: 62 _________________________________
# ***** fetch 100 articles about glider *******
# ____________________________________ remain: 61 _________________________________
# ***** fetch 100 articles about bomber *******
# ____________________________________ remain: 60 _________________________________
# ***** fetch 100 articles about us *******
# ____________________________________ remain: 59 _________________________________
# ***** fetch 4 articles about inclinometer *******
# ____________________________________ remain: 58 _________________________________
# ***** fetch 5 articles about alate *******
# ____________________________________ remain: 57 _________________________________
# ***** fetch 100 articles about mosquito *******
# ____________________________________ remain: 56 _________________________________
# ***** fetch 26 articles about tractor configuration *******
# ____________________________________ remain: 55 _________________________________
# ***** fetch 100 articles about beech *******
# ____________________________________ remain: 54 _________________________________
# ***** fetch 100 articles about fuel system *******
# ____________________________________ remain: 53 _________________________________
# ***** fetch 100 articles about delta wing *******
# ____________________________________ remain: 52 _________________________________
# ***** fetch 100 articles about transportation *******
# ____________________________________ remain: 51 _________________________________
# ***** fetch 100 articles about case *******
# ____________________________________ remain: 50 _________________________________
# ***** fetch 1 articles about dipterous insect *******
# ____________________________________ remain: 49 _________________________________
# ***** fetch 100 articles about ground effect in *******
# ____________________________________ remain: 48 _________________________________
# ***** fetch 1 articles about aviate *******
# ____________________________________ remain: 47 _________________________________
# ***** fetch 100 articles about airship *******
# ____________________________________ remain: 46 _________________________________
# ***** fetch 100 articles about enemy *******
# ____________________________________ remain: 45 _________________________________
# ***** fetch 100 articles about warplane *******
# ____________________________________ remain: 44 _________________________________
# ***** fetch 0 articles about aerophobia *******
# ____________________________________ remain: 43 _________________________________
# ***** fetch 100 articles about aerospace engineer *******
# ____________________________________ remain: 42 _________________________________
# ***** fetch 100 articles about fabric covering *******
# ____________________________________ remain: 41 _________________________________
# ***** fetch 100 articles about engine *******
# ____________________________________ remain: 40 _________________________________
# ***** fetch 100 articles about world war i *******
# ____________________________________ remain: 39 _________________________________
# ***** fetch 100 articles about fuselage *******
# ____________________________________ remain: 38 _________________________________
# ***** fetch 14 articles about hydroplane *******
# ____________________________________ remain: 37 _________________________________
# ***** fetch 100 articles about artillery *******
# ____________________________________ remain: 36 _________________________________
# ***** fetch 36 articles about v-22 osprey *******
# ____________________________________ remain: 35 _________________________________
# ***** fetch 100 articles about equip *******
# ____________________________________ remain: 34 _________________________________
# ***** fetch 4 articles about blackfly *******
# ____________________________________ remain: 33 _________________________________
# ***** fetch 100 articles about performance *******
# ____________________________________ remain: 32 _________________________________
# ***** fetch 58 articles about 767 *******
# ____________________________________ remain: 31 _________________________________
# ***** fetch 100 articles about number *******
# ____________________________________ remain: 30 _________________________________
# ***** fetch 16 articles about botfly *******
# ____________________________________ remain: 29 _________________________________
# ***** fetch 100 articles about fly sheet *******
# ____________________________________ remain: 28 _________________________________
# ***** fetch 100 articles about coalition *******
# ____________________________________ remain: 27 _________________________________
# ***** fetch 0 articles about flywire *******
# ____________________________________ remain: 26 _________________________________
# ***** fetch 100 articles about class *******
# ____________________________________ remain: 25 _________________________________
# ***** fetch 1 articles about superfly *******
# ____________________________________ remain: 24 _________________________________
# ***** fetch 7 articles about wingover *******
# ____________________________________ remain: 23 _________________________________
# ***** fetch 100 articles about training *******
# ____________________________________ remain: 22 _________________________________
# ***** fetch 100 articles about crew *******
# ____________________________________ remain: 21 _________________________________
# ***** fetch 100 articles about stabilizer *******
# ____________________________________ remain: 20 _________________________________
# ***** fetch 100 articles about reference *******
# ____________________________________ remain: 19 _________________________________
# ***** fetch 89 articles about airmail *******
# ____________________________________ remain: 18 _________________________________
# ***** fetch 70 articles about fixture *******
# ____________________________________ remain: 17 _________________________________
# ***** fetch 100 articles about rocket *******
# ____________________________________ remain: 16 _________________________________
# ***** fetch 52 articles about dipteran *******
# ____________________________________ remain: 15 _________________________________
# ***** fetch 71 articles about hindenburg disaster *******
# ____________________________________ remain: 14 _________________________________
# ***** fetch 100 articles about air *******
# ____________________________________ remain: 13 _________________________________
# ***** fetch 100 articles about fuel *******
# ____________________________________ remain: 12 _________________________________
# ***** fetch 0 articles about airdash *******
# ____________________________________ remain: 11 _________________________________
# ***** fetch 100 articles about aviation *******
# ____________________________________ remain: 10 _________________________________
# ***** fetch 100 articles about aeronautics *******
# ____________________________________ remain: 9 _________________________________
# ***** fetch 100 articles about division *******
# ____________________________________ remain: 8 _________________________________
# ***** fetch 37 articles about vought *******
# ____________________________________ remain: 7 _________________________________
# ***** fetch 31 articles about overflight *******
# ____________________________________ remain: 6 _________________________________
# ***** fetch 100 articles about control *******
# ____________________________________ remain: 5 _________________________________
# ***** fetch 100 articles about basis *******
# ____________________________________ remain: 4 _________________________________
# ***** fetch 100 articles about hydrogen *******
# ____________________________________ remain: 3 _________________________________
# ***** fetch 100 articles about pilot *******
# ____________________________________ remain: 2 _________________________________
# ***** fetch 100 articles about flew *******
# ____________________________________ remain: 1 _________________________________
# ***** fetch 100 articles about tanker *******
# ____________________________________ remain: 0 _________________________________

# %%
import shutil
! mkdir -p /home/barzamini/text_processing/data/britanica_texts/dup_words_file
with open('data/britannica_l1_car_link.json', 'r') as fp:
    data = json.load(fp)

# %%
words_end_s = ['lines', 'parks', 'vehicles', 'accidents', 'trips']
for w in words_end_s:
    words_in_car_set.remove(w)
print(len(words_in_car_set))
search_words = []

# %%
check_path = 'car/'
dataset = 'dup_words_file/'
for el in data:
    if el in words_in_car_set:
        print(f"***** fetch {len(data[el])} articles about {el} *******")
        for l in data[el]:
            file_names = [f.rsplit('/', 1)[1] for f in glob.glob(f"data/britanica_texts/{check_path}*.txt")]
            l_split, r_split = l.rsplit('/', 1)
            if r_split == '':
                file_name = l_split.rsplit('/', 1)[1]
            else:
                file_name = l.rsplit('/', 1)[1]
            if file_name + '.txt' not in file_names:
                print(f" *** retrive {l, file_name} ***")
#                 retrive(l, file_name, dataset=dataset)
            else:
                print(f"already searched for {file_name}, pls copy it from car to dup")
                
                base_path = '/home/barzamini/text_processing/data/britanica_texts/'
                src = base_path + check_path + file_name + '.txt'
                dst = base_path + dataset + file_name + '.txt'
#                 print(f"copy from {base_path + check_path + file_name} to {dataset}")
                shutil.copy(src, dst)
                
        search_words.append(el)
        remain_words = list(set(words_in_car_set) - set(search_words))
        print(f'____________________________________ remain: {len(remain_words)} _________________________________')
# Out:
# ***** fetch 100 articles about automobile *******
# already searched for automobile, pls copy it from car to dup
# already searched for History-of-the-automobile, pls copy it from car to dup
# already searched for electric-automobile, pls copy it from car to dup
# already searched for Ford-and-the-automotive-revolution, pls copy it from car to dup
# already searched for Chassis, pls copy it from car to dup
# already searched for 352807, pls copy it from car to dup
# already searched for automobile, pls copy it from car to dup
# already searched for automotive-industry, pls copy it from car to dup
# already searched for 273028, pls copy it from car to dup
# already searched for Cars-Vehicles, pls copy it from car to dup
# already searched for motor-vehicle-insurance, pls copy it from car to dup
# already searched for 273030, pls copy it from car to dup
# already searched for automobile-suspension, pls copy it from car to dup
# already searched for automobile-club, pls copy it from car to dup
# already searched for 2, pls copy it from car to dup
# already searched for Transmission, pls copy it from car to dup
# already searched for automobile-racing, pls copy it from car to dup
# already searched for Automotive-revolution-automobile-industry, pls copy it from car to dup
# already searched for The-mass-production-of-automobiles, pls copy it from car to dup
# already searched for The-modern-industry, pls copy it from car to dup
# already searched for Model-A, pls copy it from car to dup
# already searched for Tires, pls copy it from car to dup
# already searched for Mini, pls copy it from car to dup
# already searched for Emile-Levassor, pls copy it from car to dup
# already searched for 7, pls copy it from car to dup
# already searched for The-automobile-and-mass-transportation, pls copy it from car to dup
# already searched for Impact-of-the-motor-vehicle, pls copy it from car to dup
# already searched for Brakes, pls copy it from car to dup
# already searched for Plymouth-automobile, pls copy it from car to dup
# already searched for Other-European-developments, pls copy it from car to dup
# already searched for 8, pls copy it from car to dup
# already searched for 1, pls copy it from car to dup
# already searched for Emission-controls, pls copy it from car to dup
# already searched for Toyota-Motor-Corporation, pls copy it from car to dup
# already searched for tractor-vehicle, pls copy it from car to dup
# already searched for compact-car, pls copy it from car to dup
# already searched for Alexander-Winton, pls copy it from car to dup
# already searched for Jaguar-automobile, pls copy it from car to dup
# already searched for vehicular-safety-devices, pls copy it from car to dup
# already searched for Ford-Motor-Company, pls copy it from car to dup
# already searched for Volkswagen-Group, pls copy it from car to dup
# already searched for steam-automobile, pls copy it from car to dup
# already searched for Ford-Thunderbird, pls copy it from car to dup
# already searched for motor-vehicle, pls copy it from car to dup
# already searched for Highway-development, pls copy it from car to dup
# already searched for Walter-P-Chrysler, pls copy it from car to dup
# already searched for Land-Rover, pls copy it from car to dup
# already searched for Automobiles-trucks-and-airplanes, pls copy it from car to dup
# already searched for Alexandre-Darracq, pls copy it from car to dup
# already searched for Growth-in-Europe, pls copy it from car to dup
# already searched for sports-car, pls copy it from car to dup
# already searched for National-Traffic-and-Motor-Vehicle-Safety-Act, pls copy it from car to dup
# already searched for differential-gear, pls copy it from car to dup
# already searched for related, pls copy it from car to dup
# already searched for Daimler-AG, pls copy it from car to dup
# already searched for Sales-and-service-organization, pls copy it from car to dup
# already searched for Ford-Mustang, pls copy it from car to dup
# already searched for Karl-Benz, pls copy it from car to dup
# already searched for Cooling-system, pls copy it from car to dup
# already searched for main?page=1, pls copy it from car to dup
# already searched for DeLorean-DMC-12, pls copy it from car to dup
# already searched for Mini-Cooper, pls copy it from car to dup
# already searched for Cadillac-car, pls copy it from car to dup
# already searched for American-Motors-Corporation, pls copy it from car to dup
# already searched for Renault, pls copy it from car to dup
# already searched for power-steering, pls copy it from car to dup
# already searched for General-Motors-Corporation, pls copy it from car to dup
# already searched for main?page=4, pls copy it from car to dup
# already searched for Duesenberg, pls copy it from car to dup
# already searched for Siegfried-Marcus, pls copy it from car to dup
# already searched for emission-control-system, pls copy it from car to dup
# already searched for electrical-system, pls copy it from car to dup
# already searched for Alternative-fuel-vehicles, pls copy it from car to dup
# already searched for Caravan-American-automobile, pls copy it from car to dup
# already searched for 2397, pls copy it from car to dup
# already searched for Studebaker-family, pls copy it from car to dup
# already searched for Ford-999, pls copy it from car to dup
# already searched for Unsafe-at-Any-Speed, pls copy it from car to dup
# already searched for David-Dunbar-Buick, pls copy it from car to dup
# already searched for jeep, pls copy it from car to dup
# already searched for Model-T, pls copy it from car to dup
# already searched for 4, pls copy it from car to dup
# already searched for 9, pls copy it from car to dup
# already searched for Federation-Internationale-de-lAutomobile, pls copy it from car to dup
# already searched for United-Automobile-Workers, pls copy it from car to dup
# already searched for Vincent-Bendix, pls copy it from car to dup
# already searched for Europe-after-World-War-II, pls copy it from car to dup
# already searched for Charles-E-Duryea, pls copy it from car to dup
# already searched for Type-41-Bugatti, pls copy it from car to dup
# already searched for Maserati, pls copy it from car to dup
# already searched for Clement-Studebaker, pls copy it from car to dup
# already searched for Tesla-Roadster, pls copy it from car to dup
# already searched for Francis-Edgar-Stanley, pls copy it from car to dup
# already searched for torsion-bar, pls copy it from car to dup
# already searched for Henry-Ford, pls copy it from car to dup
# already searched for Elwood-Haynes, pls copy it from car to dup
# already searched for Edsel, pls copy it from car to dup
# already searched for J-Frank-Duryea, pls copy it from car to dup
# already searched for Oldsmobile, pls copy it from car to dup
# already searched for rally-automobile-racing, pls copy it from car to dup
# ____________________________________ remain: 59 _________________________________
# ***** fetch 100 articles about line *******
# already searched for line-mathematics, pls copy it from car to dup
# already searched for 353174, pls copy it from car to dup
# already searched for line-staff-management, pls copy it from car to dup
# already searched for line-graph, pls copy it from car to dup
# already searched for line-of-force, pls copy it from car to dup
# already searched for line-squall, pls copy it from car to dup
# already searched for line-fishing, pls copy it from car to dup
# already searched for stanza, pls copy it from car to dup
# already searched for sight-line, pls copy it from car to dup
# already searched for pencil-geometry, pls copy it from car to dup
# already searched for contour-line, pls copy it from car to dup
# already searched for line-spectrum, pls copy it from car to dup
# already searched for parallel-lines-geometry, pls copy it from car to dup
# already searched for tangent-of-a-curve, pls copy it from car to dup
# already searched for line-and-wash-drawing, pls copy it from car to dup
# already searched for line-radiation, pls copy it from car to dup
# already searched for line-drilling, pls copy it from car to dup
# already searched for slope-mathematics, pls copy it from car to dup
# already searched for cylinder-mathematics, pls copy it from car to dup
# already searched for cycloid, pls copy it from car to dup
# already searched for line-defect, pls copy it from car to dup
# already searched for line-of-apsides, pls copy it from car to dup
# already searched for line-fibre, pls copy it from car to dup
# already searched for line-orienteering, pls copy it from car to dup
# already searched for plumb-line, pls copy it from car to dup
# already searched for Mason-and-Dixon-Line, pls copy it from car to dup
# already searched for Hidden-lines, pls copy it from car to dup
# already searched for line-broadening, pls copy it from car to dup
# already searched for spectral-line, pls copy it from car to dup
# already searched for line-plate, pls copy it from car to dup
# already searched for asymptote, pls copy it from car to dup
# already searched for line-intaglio, pls copy it from car to dup
# already searched for International-Date-Line, pls copy it from car to dup
# already searched for broken-backed-line, pls copy it from car to dup
# already searched for latitude, pls copy it from car to dup
# already searched for fall-line, pls copy it from car to dup
# already searched for line-fishing-tackle, pls copy it from car to dup
# already searched for what-is-the-equation-for-the-perpendicular-bisector-of-the-line-segment-whose-endpoints-are-5-3-and-7-7, pls copy it from car to dup
# already searched for 150937, pls copy it from car to dup
# already searched for Arctic-Circle, pls copy it from car to dup
# already searched for dislocation-line, pls copy it from car to dup
# already searched for assembly-line, pls copy it from car to dup
# already searched for alexandrine, pls copy it from car to dup
# already searched for absorption-line, pls copy it from car to dup
# already searched for forbidden-lines, pls copy it from car to dup
# already searched for line-of-credit, pls copy it from car to dup
# already searched for D-lines, pls copy it from car to dup
# already searched for Z-line, pls copy it from car to dup
# already searched for linear-perspective, pls copy it from car to dup
# already searched for 275388, pls copy it from car to dup
# already searched for raster-line, pls copy it from car to dup
# already searched for loxodrome, pls copy it from car to dup
# already searched for Japanese-Imperial-line, pls copy it from car to dup
# already searched for hyperbolic-geometry, pls copy it from car to dup
# already searched for Stokes-lines, pls copy it from car to dup
# already searched for McMahon-Line, pls copy it from car to dup
# already searched for line-of-battle, pls copy it from car to dup
# already searched for meridian-geography, pls copy it from car to dup
# already searched for snow-line-topography, pls copy it from car to dup
# already searched for Euclidean-geometry, pls copy it from car to dup
# already searched for 53246, pls copy it from car to dup
# already searched for Maginot-Line, pls copy it from car to dup
# already searched for ship-of-the-line, pls copy it from car to dup
# already searched for Line-of-Rail, pls copy it from car to dup
# already searched for non-Euclidean-geometry, pls copy it from car to dup
# already searched for seventeenth-parallel, pls copy it from car to dup
# already searched for instant-messaging, pls copy it from car to dup
# already searched for line-out, pls copy it from car to dup
# already searched for line-prosody, pls copy it from car to dup
# already searched for equilibrium-line, pls copy it from car to dup
# already searched for haiku, pls copy it from car to dup
# already searched for pentameter, pls copy it from car to dup
# already searched for straight-line-depreciation, pls copy it from car to dup
# already searched for parallel-postulate, pls copy it from car to dup
# already searched for lateral-line-system, pls copy it from car to dup
# already searched for Fraunhofer-lines, pls copy it from car to dup
# already searched for 38th-parallel, pls copy it from car to dup
# already searched for golden-ratio, pls copy it from car to dup
# already searched for Treaty-of-Tordesillas, pls copy it from car to dup
# already searched for 274261, pls copy it from car to dup
# already searched for in-line-engine, pls copy it from car to dup
# already searched for Bandung-line, pls copy it from car to dup
# already searched for headless-line, pls copy it from car to dup
# already searched for 353366, pls copy it from car to dup
# already searched for 216757, pls copy it from car to dup
# already searched for line-of-arrested-growth, pls copy it from car to dup
# already searched for line-art, pls copy it from car to dup
# already searched for spectral-line-series, pls copy it from car to dup
# already searched for Durand-Line, pls copy it from car to dup
# already searched for anti-Stokes-lines, pls copy it from car to dup
# already searched for Greenwich-meridian, pls copy it from car to dup
# already searched for broken-line-graph, pls copy it from car to dup
# already searched for projective-geometry, pls copy it from car to dup
# already searched for Descriptive-geometry, pls copy it from car to dup
# already searched for derivative-mathematics, pls copy it from car to dup
# already searched for delay-line, pls copy it from car to dup
# already searched for catenary, pls copy it from car to dup
# already searched for forest-line, pls copy it from car to dup
# already searched for Equator, pls copy it from car to dup
# already searched for tetrameter, pls copy it from car to dup
# ____________________________________ remain: 58 _________________________________
# ***** fetch 100 articles about control *******
# already searched for control-group, pls copy it from car to dup
# already searched for control-system, pls copy it from car to dup
# already searched for 632993, pls copy it from car to dup
# already searched for control-theory-sociology, pls copy it from car to dup
# already searched for control-unit, pls copy it from car to dup
# already searched for control-law, pls copy it from car to dup
# already searched for control-theory-mathematics, pls copy it from car to dup
# already searched for Control-of-large-systems, pls copy it from car to dup
# already searched for feedback-control-electronics, pls copy it from car to dup
# already searched for general-control, pls copy it from car to dup
# already searched for cybernetics, pls copy it from car to dup
# already searched for control-problem, pls copy it from car to dup
# already searched for Feedback-controls, pls copy it from car to dup
# already searched for Control-functions, pls copy it from car to dup
# already searched for control-column, pls copy it from car to dup
# already searched for Computer-process-control, pls copy it from car to dup
# already searched for remote-control, pls copy it from car to dup
# already searched for control-system, pls copy it from car to dup
# already searched for hunting-control-system, pls copy it from car to dup
# already searched for fire-control, pls copy it from car to dup
# already searched for controller-technology, pls copy it from car to dup
# already searched for traffic-control, pls copy it from car to dup
# already searched for control-gate, pls copy it from car to dup
# already searched for strategic-control, pls copy it from car to dup
# already searched for lower-control-limit, pls copy it from car to dup
# already searched for inventory-control, pls copy it from car to dup
# already searched for numerical-control, pls copy it from car to dup
# already searched for birth-control, pls copy it from car to dup
# already searched for command-and-control-system, pls copy it from car to dup
# already searched for process-control, pls copy it from car to dup
# already searched for control-chart, pls copy it from car to dup
# already searched for gun-control-in-the-us, pls copy it from car to dup
# already searched for servomechanism, pls copy it from car to dup
# already searched for Control-of-gases, pls copy it from car to dup
# already searched for output-control-system, pls copy it from car to dup
# already searched for command-and-control-legislation, pls copy it from car to dup
# already searched for Means-of-artistic-control, pls copy it from car to dup
# already searched for system-software, pls copy it from car to dup
# already searched for Thrust-controls, pls copy it from car to dup
# already searched for Management-and-control-of-companies, pls copy it from car to dup
# already searched for actuating-device, pls copy it from car to dup
# already searched for arms-control, pls copy it from car to dup
# already searched for Common-control-techniques, pls copy it from car to dup
# already searched for efficiency-control, pls copy it from car to dup
# already searched for statistical-quality-control, pls copy it from car to dup
# already searched for automatic-feedback-control-system, pls copy it from car to dup
# already searched for Control-of-breathing, pls copy it from car to dup
# already searched for quality-control, pls copy it from car to dup
# already searched for statistical-process-control, pls copy it from car to dup
# already searched for gun-control, pls copy it from car to dup
# already searched for biological-control, pls copy it from car to dup
# already searched for control-grid, pls copy it from car to dup
# already searched for coup-detat, pls copy it from car to dup
# already searched for pollution-control, pls copy it from car to dup
# already searched for air-pollution-control, pls copy it from car to dup
# already searched for collective-pitch-control, pls copy it from car to dup
# already searched for computer-control-system, pls copy it from car to dup
# already searched for Social-control-of-propaganda, pls copy it from car to dup
# already searched for control-rod, pls copy it from car to dup
# already searched for profitability-control, pls copy it from car to dup
# already searched for communism, pls copy it from car to dup
# already searched for Numerical-control, pls copy it from car to dup
# already searched for natural-experiment, pls copy it from car to dup
# already searched for Arms-control, pls copy it from car to dup
# already searched for Control-of-disease, pls copy it from car to dup
# already searched for feedback-control-biology, pls copy it from car to dup
# already searched for control-console, pls copy it from car to dup
# already searched for central-processing-unit, pls copy it from car to dup
# already searched for Cybernetics-or-Control-and-Communication-in-the-Animal-and-the-Machine, pls copy it from car to dup
# already searched for emission-control-system, pls copy it from car to dup
# already searched for upper-control-limit, pls copy it from car to dup
# already searched for control-program, pls copy it from car to dup
# already searched for Control-structures, pls copy it from car to dup
# already searched for feedforward-control, pls copy it from car to dup
# already searched for arithmetic-logic-unit, pls copy it from car to dup
# already searched for horizontal-hold-control, pls copy it from car to dup
# already searched for cyclic-pitch-control, pls copy it from car to dup
# already searched for fluidics, pls copy it from car to dup
# already searched for contrast-control, pls copy it from car to dup
# already searched for Road-traffic-control, pls copy it from car to dup
# already searched for closed-loop-feedback-control-system, pls copy it from car to dup
# already searched for social-control, pls copy it from car to dup
# already searched for Adaptive-control, pls copy it from car to dup
# already searched for The-control-of-war, pls copy it from car to dup
# already searched for automation, pls copy it from car to dup
# already searched for fire-prevention-and-control, pls copy it from car to dup
# already searched for case-control-study, pls copy it from car to dup
# already searched for saturation-control, pls copy it from car to dup
# already searched for Ship-maneuvering-and-directional-control, pls copy it from car to dup
# already searched for oligarchy, pls copy it from car to dup
# already searched for automatic-fine-tuning-control, pls copy it from car to dup
# already searched for regulation, pls copy it from car to dup
# already searched for control-baseball, pls copy it from car to dup
# already searched for annual-plan-control, pls copy it from car to dup
# already searched for Patterns-of-control, pls copy it from car to dup
# already searched for emission-control-system, pls copy it from car to dup
# already searched for control-structure, pls copy it from car to dup
# already searched for 277407, pls copy it from car to dup
# already searched for hierarchy-control, pls copy it from car to dup
# already searched for Information-systems-audit, pls copy it from car to dup
# ____________________________________ remain: 57 _________________________________
# ***** fetch 100 articles about walk *******
# already searched for walking-recreation, pls copy it from car to dup
# already searched for walk, pls copy it from car to dup
# already searched for walking-form-of-locomotion, pls copy it from car to dup
# already searched for running-walk, pls copy it from car to dup
# already searched for hiking, pls copy it from car to dup
# already searched for race-walking, pls copy it from car to dup
# already searched for Walking-Purchase, pls copy it from car to dup
# already searched for fire-walking, pls copy it from car to dup
# already searched for random-walk, pls copy it from car to dup
# already searched for relaxed-walk, pls copy it from car to dup
# already searched for bipedalism, pls copy it from car to dup
# already searched for Walk-off-the-Earth, pls copy it from car to dup
# already searched for are-cows-really-unable-to-walk-down-stairs, pls copy it from car to dup
# already searched for lesson-racewalking-rules-sports, pls copy it from car to dup
# already searched for stride, pls copy it from car to dup
# already searched for walk-marching-pace-horse-feet-beat-another, pls copy it from car to dup
# already searched for drunkards-walk, pls copy it from car to dup
# already searched for A-Walk-on-the-Water-by-Stoppard, pls copy it from car to dup
# already searched for walking-catfish, pls copy it from car to dup
# already searched for Tennessee-walking-horse, pls copy it from car to dup
# already searched for Terrestrial-locomotion, pls copy it from car to dup
# already searched for a-good-walk-spoiled, pls copy it from car to dup
# already searched for Walk-Dont-Run-song-by-the-Ventures, pls copy it from car to dup
# already searched for A-Walk-in-the-Night, pls copy it from car to dup
# already searched for rope-walk, pls copy it from car to dup
# already searched for gait, pls copy it from car to dup
# already searched for terrestrial-locomotion, pls copy it from car to dup
# already searched for plantigrade-posture, pls copy it from car to dup
# already searched for walking-fern, pls copy it from car to dup
# already searched for knuckle-walking, pls copy it from car to dup
# already searched for quadrupedalism, pls copy it from car to dup
# already searched for promenade, pls copy it from car to dup
# already searched for symmetric-random-walk, pls copy it from car to dup
# already searched for the-first-space-walk, pls copy it from car to dup
# already searched for spacewalk, pls copy it from car to dup
# already searched for Konigsberg-bridge-problem, pls copy it from car to dup
# already searched for Walk-Softly-Stranger, pls copy it from car to dup
# already searched for Philippe-Petit, pls copy it from car to dup
# already searched for leaf-insect, pls copy it from car to dup
# already searched for The-Morning-Walk, pls copy it from car to dup
# already searched for gait-analysis, pls copy it from car to dup
# already searched for A-Walk-on-the-Wild-Side-novel, pls copy it from car to dup
# already searched for Feeding-habits, pls copy it from car to dup
# already searched for base-on-balls, pls copy it from car to dup
# already searched for The-Walk-to-Paradise-Garden, pls copy it from car to dup
# already searched for piaffe, pls copy it from car to dup
# already searched for digitigrade-posture, pls copy it from car to dup
# already searched for Walking-and-flying, pls copy it from car to dup
# already searched for athletics, pls copy it from car to dup
# already searched for Tony-Robbins, pls copy it from car to dup
# already searched for Orange-Walk, pls copy it from car to dup
# already searched for friction, pls copy it from car to dup
# already searched for Duchenne-muscular-dystrophy, pls copy it from car to dup
# already searched for Verklarte-Nacht, pls copy it from car to dup
# already searched for A-Walk-with-Love-and-Death, pls copy it from car to dup
# already searched for rectilinear-locomotion, pls copy it from car to dup
# already searched for human-evolution, pls copy it from car to dup
# already searched for Walk-the-Line, pls copy it from car to dup
# already searched for hindtoe, pls copy it from car to dup
# already searched for tarsal, pls copy it from car to dup
# already searched for foot, pls copy it from car to dup
# already searched for running-athletics, pls copy it from car to dup
# already searched for horsemanship, pls copy it from car to dup
# already searched for Shoes-Walking-on-My-Brain, pls copy it from car to dup
# already searched for Ivar-the-Boneless, pls copy it from car to dup
# already searched for was-the-big-bang-actually-an-explosion, pls copy it from car to dup
# already searched for Locomotion, pls copy it from car to dup
# already searched for Locomotion, pls copy it from car to dup
# already searched for Trivia-or-The-Art-of-Walking-the-Streets-of-London, pls copy it from car to dup
# already searched for multitasking, pls copy it from car to dup
# already searched for mountaineering, pls copy it from car to dup
# already searched for whats-the-difference-between-seals-and-sea-lions, pls copy it from car to dup
# already searched for sleepwalking, pls copy it from car to dup
# already searched for collection-horsemanship, pls copy it from car to dup
# already searched for allee, pls copy it from car to dup
# already searched for walk-like-an-egyptian, pls copy it from car to dup
# already searched for Form-and-function, pls copy it from car to dup
# already searched for how-do-we-know-how-far-away-the-stars-are, pls copy it from car to dup
# already searched for chimpanzee, pls copy it from car to dup
# already searched for Walking-Woman, pls copy it from car to dup
# already searched for intentional-walk, pls copy it from car to dup
# already searched for Evolutionary-context, pls copy it from car to dup
# already searched for Kaaba-shrine-Mecca-Saudi-Arabia, pls copy it from car to dup
# already searched for nuthatch, pls copy it from car to dup
# already searched for inflection, pls copy it from car to dup
# already searched for monkey, pls copy it from car to dup
# already searched for walking-and-other-philosophical-exercises, pls copy it from car to dup
# already searched for 10-ways-to-improve-your-curiosity.html, pls copy it from car to dup
# already searched for power-struggle-Henry-IV-Gregory-VII, pls copy it from car to dup
# already searched for Economy, pls copy it from car to dup
# already searched for strong-el-nino-expected-to-peak-in-late-2015, pls copy it from car to dup
# already searched for I-Walk-Alone, pls copy it from car to dup
# already searched for how-many-people-have-been-to-the-moon, pls copy it from car to dup
# already searched for spiders-water-surface, pls copy it from car to dup
# already searched for titanosaurs-8-of-the-worlds-biggest-dinosaurs, pls copy it from car to dup
# already searched for role-pheromones-human-attraction, pls copy it from car to dup
# already searched for cloister, pls copy it from car to dup
# already searched for perseid-meteor-shower, pls copy it from car to dup
# already searched for heel-anatomy, pls copy it from car to dup
# already searched for mudskipper, pls copy it from car to dup
# ____________________________________ remain: 56 _________________________________
# ***** fetch 100 articles about lot *******
# already searched for lot-astrology, pls copy it from car to dup
# already searched for sortition, pls copy it from car to dup
# already searched for Lot-River, pls copy it from car to dup
# already searched for Lots-wife, pls copy it from car to dup
# already searched for Sodom-and-Gomorrah, pls copy it from car to dup
# already searched for statistical-quality-control, pls copy it from car to dup
# already searched for Lot-biblical-figure, pls copy it from car to dup
# already searched for Lot-et-Garonne, pls copy it from car to dup
# already searched for Moabite, pls copy it from car to dup
# already searched for Kamehameha-V, pls copy it from car to dup
# already searched for to-navigate-the-dangers-of-the-web-you-need-critical-thinking--but-also-critical-ignoring, pls copy it from car to dup
# already searched for Purim, pls copy it from car to dup
# already searched for Internet, pls copy it from car to dup
# already searched for whats-the-difference-between-bluetooth-and-wi-fi, pls copy it from car to dup
# already searched for computer, pls copy it from car to dup
# already searched for The-Crying-of-Lot-49, pls copy it from car to dup
# already searched for beriberi, pls copy it from car to dup
# already searched for ENIAC, pls copy it from car to dup
# already searched for mitochondrion, pls copy it from car to dup
# already searched for deafness-on-Marthas-Vineyard, pls copy it from car to dup
# already searched for Ferdinand-Lot, pls copy it from car to dup
# already searched for 632993, pls copy it from car to dup
# already searched for massive-flare-seen-on-the-closest-star-to-the-solar-system, pls copy it from car to dup
# already searched for Empty-Lot, pls copy it from car to dup
# already searched for Poseidon, pls copy it from car to dup
# already searched for Council-of-Five-Hundred-ancient-Greek-council, pls copy it from car to dup
# already searched for The-Rough-and-Ready-Lot, pls copy it from car to dup
# already searched for Midi-Pyrenees, pls copy it from car to dup
# already searched for Northwest-Ordinances, pls copy it from car to dup
# already searched for Hades-Greek-mythology, pls copy it from car to dup
# already searched for The-Fourth-Industrial-Revolution-2119734, pls copy it from car to dup
# already searched for it-takes-a-lot-of-energy-for-machines-to-learn--heres-why-ai-is-so-power-hungry, pls copy it from car to dup
# already searched for servitude-property-law, pls copy it from car to dup
# already searched for why-are-flamingos-pink, pls copy it from car to dup
# already searched for Guyenne, pls copy it from car to dup
# already searched for The-publics-hatred-of-Socrates, pls copy it from car to dup
# already searched for how-rye-bread-may-have-caused-the-salem-witch-trials, pls copy it from car to dup
# already searched for Warner-Brothers, pls copy it from car to dup
# already searched for Time-Warner-Inc, pls copy it from car to dup
# already searched for Great-Dionysia, pls copy it from car to dup
# already searched for Melchizedek, pls copy it from car to dup
# already searched for do-we-really-swallow-spiders-in-our-sleep, pls copy it from car to dup
# already searched for 7-lakes-that-are-drying-up, pls copy it from car to dup
# already searched for democracy, pls copy it from car to dup
# already searched for license, pls copy it from car to dup
# already searched for whats-inside-the-great-pyramid, pls copy it from car to dup
# already searched for Raising-curious-learners-creative-play, pls copy it from car to dup
# already searched for Land-policy-in-New-England-and-Virginia, pls copy it from car to dup
# already searched for why-do-americans-celebrate-independence-day-with-fireworks, pls copy it from car to dup
# already searched for why-do-cats-sleep-so-much, pls copy it from car to dup
# already searched for sebaceous-gland, pls copy it from car to dup
# already searched for Cahors, pls copy it from car to dup
# already searched for high-priest, pls copy it from car to dup
# already searched for boule-ancient-Greek-council, pls copy it from car to dup
# already searched for coffee, pls copy it from car to dup
# already searched for sweating-sickness, pls copy it from car to dup
# already searched for Discussion-forces-bodies-water, pls copy it from car to dup
# already searched for ecumenism, pls copy it from car to dup
# already searched for heres-what-really-happened-to-shamu, pls copy it from car to dup
# already searched for Aquitaine, pls copy it from car to dup
# already searched for History, pls copy it from car to dup
# already searched for acceleration-stress, pls copy it from car to dup
# already searched for nitrogen-narcosis, pls copy it from car to dup
# already searched for decompression-sickness, pls copy it from car to dup
# already searched for whats-the-difference-between-the-deep-web-and-the-dark-web, pls copy it from car to dup
# already searched for why-are-so-many-koreans-named-kim, pls copy it from car to dup
# already searched for 5-awesome-parasitic-plants, pls copy it from car to dup
# already searched for how-many-tyrannosaurus-rex-walked-the-earth, pls copy it from car to dup
# already searched for neurosis, pls copy it from car to dup
# already searched for mineral-processing, pls copy it from car to dup
# already searched for cowpox, pls copy it from car to dup
# already searched for Thomas-Pynchon, pls copy it from car to dup
# already searched for scarlet-fever, pls copy it from car to dup
# already searched for why-do-some-animals-hibernate, pls copy it from car to dup
# already searched for The-objectives-of-biological-classification, pls copy it from car to dup
# already searched for histoplasmosis, pls copy it from car to dup
# already searched for celebrity-a-little-bad-a-lot-of-good, pls copy it from car to dup
# already searched for dragon-boating-introduction-boat-sport-team-paddlers, pls copy it from car to dup
# already searched for the-canadian-football-league-10-claims-to-fame, pls copy it from car to dup
# already searched for Palace-of-Versailles, pls copy it from car to dup
# already searched for acceptance-sampling, pls copy it from car to dup
# already searched for choragus, pls copy it from car to dup
# already searched for how-much-trash-is-in-space, pls copy it from car to dup
# already searched for cleromancy, pls copy it from car to dup
# already searched for Settlement-patterns, pls copy it from car to dup
# already searched for Mexico-City, pls copy it from car to dup
# already searched for pernicious-anemia, pls copy it from car to dup
# already searched for Hippocratic-oath, pls copy it from car to dup
# already searched for carpal-tunnel-syndrome, pls copy it from car to dup
# already searched for The-Viking-era, pls copy it from car to dup
# already searched for ecosystems, pls copy it from car to dup
# already searched for whats-the-difference-between-llamas-and-alpacas, pls copy it from car to dup
# already searched for Agamemnon-Greek-mythology, pls copy it from car to dup
# already searched for Rocamadour, pls copy it from car to dup
# already searched for Culture, pls copy it from car to dup
# already searched for factory-system, pls copy it from car to dup
# already searched for retailing, pls copy it from car to dup
# already searched for lung-congestion, pls copy it from car to dup
# already searched for was-elizabeth-i-a-popular-queen, pls copy it from car to dup
# already searched for laceration, pls copy it from car to dup
# ____________________________________ remain: 55 _________________________________
# ***** fetch 100 articles about driver *******
# already searched for driver-computer-program, pls copy it from car to dup
# already searched for driver-ant, pls copy it from car to dup
# already searched for system-software, pls copy it from car to dup
# already searched for pile-driver, pls copy it from car to dup
# already searched for driving-and-coaching, pls copy it from car to dup
# already searched for driving-hunting, pls copy it from car to dup
# already searched for mass-driver, pls copy it from car to dup
# already searched for WordPress, pls copy it from car to dup
# already searched for 273029, pls copy it from car to dup
# already searched for Lewis-Hamilton, pls copy it from car to dup
# already searched for Driving-Miss-Daisy-film-by-Beresford, pls copy it from car to dup
# already searched for information-system, pls copy it from car to dup
# already searched for Niki-Lauda, pls copy it from car to dup
# already searched for Adam-Driver, pls copy it from car to dup
# already searched for self-drivingtaxis-could-be-a-setback-for-those-with-different-needs, pls copy it from car to dup
# already searched for Danica-Patrick, pls copy it from car to dup
# already searched for Al-Unser, pls copy it from car to dup
# already searched for Sebastian-Vettel, pls copy it from car to dup
# already searched for Helio-Castroneves, pls copy it from car to dup
# already searched for Janet-Guthrie, pls copy it from car to dup
# already searched for automobile-racing, pls copy it from car to dup
# already searched for Ned-Jarrett, pls copy it from car to dup
# already searched for James-Hunt, pls copy it from car to dup
# already searched for human-factors-engineering, pls copy it from car to dup
# already searched for Michael-Schumacher, pls copy it from car to dup
# already searched for Jeff-Gordon, pls copy it from car to dup
# already searched for Tazio-Nuvolari, pls copy it from car to dup
# already searched for Jack-Brabham, pls copy it from car to dup
# already searched for Grand-Prix-racing, pls copy it from car to dup
# already searched for Sebastien-Loeb, pls copy it from car to dup
# already searched for John-D-Campbell, pls copy it from car to dup
# already searched for Richard-Petty-American-stock-car-racer, pls copy it from car to dup
# already searched for Jimmie-Johnson, pls copy it from car to dup
# already searched for Juan-Manuel-Fangio, pls copy it from car to dup
# already searched for operating-system, pls copy it from car to dup
# already searched for Lee-Petty, pls copy it from car to dup
# already searched for Mario-Andretti, pls copy it from car to dup
# already searched for Herve-Filion, pls copy it from car to dup
# already searched for Louis-Chevrolet, pls copy it from car to dup
# already searched for Daytona-500, pls copy it from car to dup
# already searched for Taxi-Driver, pls copy it from car to dup
# already searched for A-J-Foyt, pls copy it from car to dup
# already searched for Phil-Hill, pls copy it from car to dup
# already searched for rally-automobile-racing, pls copy it from car to dup
# already searched for pinion, pls copy it from car to dup
# already searched for Bobby-Unser, pls copy it from car to dup
# already searched for Barney-Oldfield, pls copy it from car to dup
# already searched for power-steering, pls copy it from car to dup
# already searched for Dale-Earnhardt, pls copy it from car to dup
# already searched for Jacques-Villeneuve, pls copy it from car to dup
# already searched for wagonette, pls copy it from car to dup
# already searched for Art-Arfons, pls copy it from car to dup
# already searched for NASCAR, pls copy it from car to dup
# already searched for traffic-control, pls copy it from car to dup
# already searched for Bernd-Rosemeyer, pls copy it from car to dup
# already searched for driver-beam, pls copy it from car to dup
# already searched for vehicular-safety-devices, pls copy it from car to dup
# already searched for John-Michael-Hawthorn, pls copy it from car to dup
# already searched for hansom-cab, pls copy it from car to dup
# already searched for Junior-Johnson, pls copy it from car to dup
# already searched for drag-racing, pls copy it from car to dup
# already searched for Robert-De-Niro, pls copy it from car to dup
# already searched for Crash-film-by-Haggis, pls copy it from car to dup
# already searched for collaborative-software, pls copy it from car to dup
# already searched for hardware-computing, pls copy it from car to dup
# already searched for Sir-Henry-ONeal-de-Hane-Segrave, pls copy it from car to dup
# already searched for David-Pearson, pls copy it from car to dup
# already searched for road, pls copy it from car to dup
# already searched for snowmobile, pls copy it from car to dup
# already searched for cabriolet, pls copy it from car to dup
# already searched for Giuseppe-Farina, pls copy it from car to dup
# already searched for Tony-Shalhoub, pls copy it from car to dup
# already searched for Rudolf-Caracciola, pls copy it from car to dup
# already searched for Bobby-Allison, pls copy it from car to dup
# already searched for data-mining, pls copy it from car to dup
# already searched for clutch-machine-component, pls copy it from car to dup
# already searched for Bill-France-Sr, pls copy it from car to dup
# already searched for 273028, pls copy it from car to dup
# already searched for American-bittern, pls copy it from car to dup
# already searched for 24-Hours-of-Le-Mans, pls copy it from car to dup
# already searched for Winners-of-24-Hours-of-Le-Mans, pls copy it from car to dup
# already searched for 476269, pls copy it from car to dup
# already searched for measurement-scale, pls copy it from car to dup
# already searched for rickshaw-vehicle, pls copy it from car to dup
# already searched for Unsafe-at-Any-Speed, pls copy it from car to dup
# already searched for Baby-Driver, pls copy it from car to dup
# already searched for drive-side-British-road, pls copy it from car to dup
# already searched for go-kart, pls copy it from car to dup
# already searched for Stirling-Moss, pls copy it from car to dup
# already searched for Ralph-De-Palma, pls copy it from car to dup
# already searched for Sprint-Cup-Series, pls copy it from car to dup
# already searched for the-riots-of-the-long-hot-summer, pls copy it from car to dup
# already searched for Geneva-mechanism, pls copy it from car to dup
# already searched for multitasking-to-death, pls copy it from car to dup
# already searched for Donald-Malcolm-Campbell, pls copy it from car to dup
# already searched for horsecar, pls copy it from car to dup
# already searched for traffic-law, pls copy it from car to dup
# already searched for drive, pls copy it from car to dup
# already searched for mother-of-the-civil-rights-movement, pls copy it from car to dup
# already searched for karting, pls copy it from car to dup
# ____________________________________ remain: 54 _________________________________
# ***** fetch 100 articles about street *******
# already searched for street-photography, pls copy it from car to dup
# already searched for street-film, pls copy it from car to dup
# already searched for road, pls copy it from car to dup
# already searched for street-style-skateboarding, pls copy it from car to dup
# already searched for Broadway-street-and-district-New-York-City, pls copy it from car to dup
# already searched for 276743, pls copy it from car to dup
# already searched for gang-crime, pls copy it from car to dup
# already searched for The-Street-novel-by-Petry, pls copy it from car to dup
# already searched for street-photography-how-a-single-camera-brought-about-a-genre, pls copy it from car to dup
# already searched for Street-of-the-Dead, pls copy it from car to dup
# already searched for Times-Square, pls copy it from car to dup
# already searched for streetcar, pls copy it from car to dup
# already searched for Harlem-New-York, pls copy it from car to dup
# already searched for Wall-Street-New-York-City, pls copy it from car to dup
# already searched for Street-Scene-play-by-Rice, pls copy it from car to dup
# already searched for Black-Wall-Street, pls copy it from car to dup
# already searched for After-World-War-II, pls copy it from car to dup
# already searched for skateboarding, pls copy it from car to dup
# already searched for graffiti-art, pls copy it from car to dup
# already searched for the-Loop, pls copy it from car to dup
# already searched for Street-Berlin, pls copy it from car to dup
# already searched for Grub-Street, pls copy it from car to dup
# already searched for Crips, pls copy it from car to dup
# already searched for City-layout, pls copy it from car to dup
# already searched for street-luge, pls copy it from car to dup
# already searched for break-dance, pls copy it from car to dup
# already searched for City-layout, pls copy it from car to dup
# already searched for Banksy, pls copy it from car to dup
# already searched for 10-Downing-Street, pls copy it from car to dup
# already searched for Walnut-Street-Theatre, pls copy it from car to dup
# already searched for Washington-DC, pls copy it from car to dup
# already searched for Boylston-Street, pls copy it from car to dup
# already searched for Peter-Street, pls copy it from car to dup
# already searched for U-Street, pls copy it from car to dup
# already searched for Paris, pls copy it from car to dup
# already searched for Rashid-Street, pls copy it from car to dup
# already searched for subway, pls copy it from car to dup
# already searched for stock-market-crash-of-1929, pls copy it from car to dup
# already searched for The-Wall-Street-Journal, pls copy it from car to dup
# already searched for pop-music-from-backstreet-to-main-street, pls copy it from car to dup
# already searched for New-York-City, pls copy it from car to dup
# already searched for City-layout, pls copy it from car to dup
# already searched for Sesame-Street, pls copy it from car to dup
# already searched for auteur-theory, pls copy it from car to dup
# already searched for Ermine-Street, pls copy it from car to dup
# already searched for City-layout, pls copy it from car to dup
# already searched for New-York-Stock-Exchange, pls copy it from car to dup
# already searched for 16th-Street-Baptist-Church-bombing, pls copy it from car to dup
# already searched for Trans-Canada-Highway, pls copy it from car to dup
# already searched for Main-Street-novel-by-Lewis, pls copy it from car to dup
# already searched for Beale-Street, pls copy it from car to dup
# already searched for Empire-State-Building, pls copy it from car to dup
# already searched for Miracle-on-34th-Street, pls copy it from car to dup
# already searched for Side-Street, pls copy it from car to dup
# already searched for Picabo-Street, pls copy it from car to dup
# already searched for Locust-Street-Social-Settlement, pls copy it from car to dup
# already searched for Roman-road-system, pls copy it from car to dup
# already searched for Calle-de-Alcala, pls copy it from car to dup
# already searched for Watling-Street, pls copy it from car to dup
# already searched for The-House-on-92nd-Street, pls copy it from car to dup
# already searched for Wangfujing-Dajie, pls copy it from car to dup
# already searched for Cotton-Club, pls copy it from car to dup
# already searched for Streets-of-Philadelphia, pls copy it from car to dup
# already searched for World-Trade-Center, pls copy it from car to dup
# already searched for performance-art, pls copy it from car to dup
# already searched for Mohamed-Bouazizi, pls copy it from car to dup
# already searched for La-Salle-Street, pls copy it from car to dup
# already searched for Dizengoff-Street, pls copy it from car to dup
# already searched for 277926, pls copy it from car to dup
# already searched for E-Street-Band, pls copy it from car to dup
# already searched for West-Side-Story-film-by-Robbins-and-Wise, pls copy it from car to dup
# already searched for The-Street-Light-Study-of-Light, pls copy it from car to dup
# already searched for Street-Girl, pls copy it from car to dup
# already searched for Occupy-Wall-Street, pls copy it from car to dup
# already searched for Abu-Nuwas-Street, pls copy it from car to dup
# already searched for horsecar, pls copy it from car to dup
# already searched for City-layout, pls copy it from car to dup
# already searched for Wall-Street-bombing-of-1920, pls copy it from car to dup
# already searched for Tin-Pan-Alley-musical-history, pls copy it from car to dup
# already searched for Bow-Street-Runner, pls copy it from car to dup
# already searched for Cato-Street-Conspiracy, pls copy it from car to dup
# already searched for A-Street-in-Bronzeville, pls copy it from car to dup
# already searched for Dublin, pls copy it from car to dup
# already searched for Johnny-Depp, pls copy it from car to dup
# already searched for Tulsa-race-massacre-of-1921, pls copy it from car to dup
# already searched for Liverpool-Street-Station, pls copy it from car to dup
# already searched for Dover-Street-Market, pls copy it from car to dup
# already searched for Osaka-Kobe-metropolitan-area, pls copy it from car to dup
# ...
# already searched for misfit-stream, pls copy it from car to dup
# already searched for levee, pls copy it from car to dup
# already searched for equatorial-current, pls copy it from car to dup
# already searched for Surface-water-and-groundwater, pls copy it from car to dup
# already searched for waterwheel-engineering, pls copy it from car to dup
# already searched for aqueduct-engineering, pls copy it from car to dup
# already searched for spring-water, pls copy it from car to dup
# already searched for Kuroshio, pls copy it from car to dup
# already searched for transverse-stream, pls copy it from car to dup
# already searched for Jet-streams, pls copy it from car to dup
# already searched for brook-hydrology, pls copy it from car to dup
# already searched for cave, pls copy it from car to dup
# already searched for Wadi-Tharthar, pls copy it from car to dup
# already searched for Volga-River, pls copy it from car to dup
# already searched for Indian-monsoon, pls copy it from car to dup
# already searched for Islands-in-the-Stream-film-by-Schaffner, pls copy it from car to dup
# already searched for Ganges-River, pls copy it from car to dup
# already searched for sidestream, pls copy it from car to dup
# already searched for Blood-River, pls copy it from car to dup
# already searched for megathermal-stream, pls copy it from car to dup
# already searched for cathode-ray, pls copy it from car to dup
# already searched for Jane-Goodall, pls copy it from car to dup
# already searched for chromatography, pls copy it from car to dup
# already searched for Chonggye-Stream, pls copy it from car to dup
# already searched for stream-tadpole, pls copy it from car to dup
# already searched for Circulation-currents-and-ocean-atmosphere-interaction, pls copy it from car to dup
# already searched for Streamflow-and-sediment-yield, pls copy it from car to dup
# ____________________________________ remain: 2 _________________________________
# ***** fetch 100 articles about downtown *******
# already searched for the-Loop, pls copy it from car to dup
# already searched for 352965, pls copy it from car to dup
# already searched for Chicago, pls copy it from car to dup
# already searched for Chicago-River, pls copy it from car to dup
# already searched for Landscape, pls copy it from car to dup
# already searched for Grant-Park, pls copy it from car to dup
# already searched for Los-Angeles-California, pls copy it from car to dup
# already searched for Cultural-life, pls copy it from car to dup
# already searched for Seattle-Washington, pls copy it from car to dup
# already searched for Washington-DC, pls copy it from car to dup
# already searched for Indianapolis-Indiana, pls copy it from car to dup
# already searched for Vancouver, pls copy it from car to dup
# already searched for Oak-Park, pls copy it from car to dup
# already searched for Chicago-fire-of-1871, pls copy it from car to dup
# already searched for Montreal, pls copy it from car to dup
# already searched for Times-Square, pls copy it from car to dup
# already searched for Las-Vegas-Nevada, pls copy it from car to dup
# already searched for Detroit, pls copy it from car to dup
# already searched for Edmonton-Alberta, pls copy it from car to dup
# already searched for Decatur-Illinois, pls copy it from car to dup
# already searched for Toronto, pls copy it from car to dup
# already searched for Saint-Paul-Minnesota, pls copy it from car to dup
# already searched for Merchandise-Mart, pls copy it from car to dup
# already searched for Oklahoma-City, pls copy it from car to dup
# already searched for Victoria-British-Columbia, pls copy it from car to dup
# already searched for Sao-Paulo-Brazil, pls copy it from car to dup
# already searched for San-Jose-Costa-Rica, pls copy it from car to dup
# already searched for New-York-state, pls copy it from car to dup
# already searched for Cairo, pls copy it from car to dup
# already searched for History, pls copy it from car to dup
# already searched for 273905, pls copy it from car to dup
# already searched for Eastland-disaster, pls copy it from car to dup
# already searched for Cleveland-Ohio, pls copy it from car to dup
# already searched for Settlement-patterns, pls copy it from car to dup
# already searched for Atlanta-Georgia, pls copy it from car to dup
# already searched for Wall-Street-bombing-of-1920, pls copy it from car to dup
# already searched for Growth-in-the-20th-century, pls copy it from car to dup
# already searched for Oslo-and-Utoya-attacks-of-2011, pls copy it from car to dup
# already searched for Helsinki, pls copy it from car to dup
# already searched for Indiana-state, pls copy it from car to dup
# already searched for Hollywood-California, pls copy it from car to dup
# already searched for New-Haven-Connecticut, pls copy it from car to dup
# already searched for assassination-of-John-F-Kennedy, pls copy it from car to dup
# already searched for Economy, pls copy it from car to dup
# already searched for Akron-Ohio, pls copy it from car to dup
# already searched for Pittsburgh, pls copy it from car to dup
# already searched for Heisman-Trophy, pls copy it from car to dup
# already searched for Midland-Texas, pls copy it from car to dup
# already searched for River-Phoenix, pls copy it from car to dup
# already searched for Harvard-University, pls copy it from car to dup
# already searched for University-of-Houston, pls copy it from car to dup
# already searched for Mexico-City, pls copy it from car to dup
# already searched for Durban, pls copy it from car to dup
# already searched for chicago, pls copy it from car to dup
# already searched for Alexandria-Egypt, pls copy it from car to dup
# already searched for Potter-Palmer, pls copy it from car to dup
# already searched for main?page=1, pls copy it from car to dup
# already searched for Shanghai, pls copy it from car to dup
# already searched for Foggy-Bottom, pls copy it from car to dup
# already searched for Joliet, pls copy it from car to dup
# already searched for Oklahoma-City-Thunder, pls copy it from car to dup
# already searched for Tulsa-race-massacre-of-1921, pls copy it from car to dup
# already searched for The-Bohemian-Club, pls copy it from car to dup
# already searched for Charlotte-North-Carolina, pls copy it from car to dup
# already searched for Monongahela-River, pls copy it from car to dup
# already searched for Tribune-Tower, pls copy it from car to dup
# already searched for Monuments-and-memorials, pls copy it from car to dup
# already searched for Golden-Triangle-region-Pittsburgh-Pennsylvania, pls copy it from car to dup
# already searched for discussion-city-rebuilding-construction-Chicago-fire-Rookery-1871, pls copy it from car to dup
# already searched for History, pls copy it from car to dup
# already searched for Back-to-the-38th-parallel, pls copy it from car to dup
# already searched for Languages, pls copy it from car to dup
# already searched for Alton-Illinois, pls copy it from car to dup
# already searched for Imogene-Coca, pls copy it from car to dup
# already searched for The-contemporary-city, pls copy it from car to dup
# already searched for Trump-International-Hotel-and-Tower-Chicago, pls copy it from car to dup
# already searched for Stamford-Connecticut, pls copy it from car to dup
# already searched for Dixieland, pls copy it from car to dup
# already searched for Atlanta-Riot-of-1906, pls copy it from car to dup
# already searched for Branson, pls copy it from car to dup
# already searched for USX-Corporation, pls copy it from car to dup
# already searched for main?page=1, pls copy it from car to dup
# already searched for main?page=1, pls copy it from car to dup
# already searched for Cultural-life, pls copy it from car to dup
# already searched for was-johnny-appleseed-a-real-person, pls copy it from car to dup
# already searched for main?page=1, pls copy it from car to dup
# already searched for Jeanne-Gang, pls copy it from car to dup
# already searched for Memphis-Tennessee, pls copy it from car to dup
# already searched for main?page=1, pls copy it from car to dup
# already searched for Aon-Center, pls copy it from car to dup
# already searched for City-site, pls copy it from car to dup
# already searched for Highland-Park-Illinois, pls copy it from car to dup
# already searched for Landscape, pls copy it from car to dup
# already searched for Los-Angeles-Riots-of-1992, pls copy it from car to dup
# already searched for Southwest-Airlines-Co, pls copy it from car to dup
# already searched for Benton-Harbor, pls copy it from car to dup
# already searched for Marina-City, pls copy it from car to dup
# already searched for Michigan-Avenue, pls copy it from car to dup
# already searched for Filippo-Brunelleschi, pls copy it from car to dup
# already searched for Inner-Harbour, pls copy it from car to dup
# ____________________________________ remain: 1 _________________________________
# ***** fetch 100 articles about problem *******
# already searched for problem, pls copy it from car to dup
# already searched for problem-finding, pls copy it from car to dup
# already searched for NP-complete-problem, pls copy it from car to dup
# already searched for problem-solving, pls copy it from car to dup
# already searched for problem-play, pls copy it from car to dup
# already searched for The-three-classical-problems, pls copy it from car to dup
# already searched for P-versus-NP-problem, pls copy it from car to dup
# already searched for collective-action-problem-1917157, pls copy it from car to dup
# already searched for tractable-problem, pls copy it from car to dup
# already searched for Features-and-problems-of-logic, pls copy it from car to dup
# already searched for NP-problem, pls copy it from car to dup
# already searched for Types-of-thinking, pls copy it from car to dup
# already searched for polynomial-time-algorithm, pls copy it from car to dup
# already searched for Features-and-problems, pls copy it from car to dup
# already searched for problem-of-evil, pls copy it from car to dup
# already searched for Algorithms-and-heuristics, pls copy it from car to dup
# already searched for Konigsberg-bridge-problem, pls copy it from car to dup
# already searched for Problems-in-metaphysics, pls copy it from car to dup
# already searched for decision-problem, pls copy it from car to dup
# already searched for Expert-thinking-and-novice-thinking, pls copy it from car to dup
# already searched for problem-of-moral-responsibility, pls copy it from car to dup
# already searched for problem-oriented-language, pls copy it from car to dup
# already searched for planar-problem, pls copy it from car to dup
# already searched for Plateau-problem, pls copy it from car to dup
# already searched for problem-of-other-minds, pls copy it from car to dup
# already searched for intractable-problem, pls copy it from car to dup
# already searched for Millennium-Problem, pls copy it from car to dup
# already searched for three-body-problem, pls copy it from car to dup
# already searched for artificial-intelligence, pls copy it from car to dup
# already searched for graph-theory, pls copy it from car to dup
# already searched for Geometric-and-algebraic-problems, pls copy it from car to dup
# already searched for The-system-design-problem, pls copy it from car to dup
# already searched for search-problem, pls copy it from car to dup
# already searched for Problems-issues-and-tasks, pls copy it from car to dup
# already searched for companionship-problem, pls copy it from car to dup
# already searched for Problems-of-ontology, pls copy it from car to dup
# already searched for Dirichlet-problem, pls copy it from car to dup
# already searched for linear-programming-mathematics, pls copy it from car to dup
# already searched for Problems-with-socialism, pls copy it from car to dup
# already searched for problem-of-induction, pls copy it from car to dup
# already searched for control-problem, pls copy it from car to dup
# already searched for Resource-allocation, pls copy it from car to dup
# already searched for NP-hard-problem, pls copy it from car to dup
# already searched for numerical-analysis, pls copy it from car to dup
# already searched for Network-routing, pls copy it from car to dup
# already searched for social-problem-novel, pls copy it from car to dup
# already searched for enumeration-problem, pls copy it from car to dup
# already searched for Essential-characteristics, pls copy it from car to dup
# already searched for Replacement-and-maintenance, pls copy it from car to dup
# already searched for pollution-overview, pls copy it from car to dup
# already searched for The-problem-of-suffering, pls copy it from car to dup
# already searched for trolley-problem, pls copy it from car to dup
# already searched for Reasoning, pls copy it from car to dup
# already searched for Hilberts-23-problems, pls copy it from car to dup
# already searched for The-measurement-problem, pls copy it from car to dup
# already searched for courier-problem, pls copy it from car to dup
# already searched for satisfiability-problem, pls copy it from car to dup
# already searched for problem-solving-environment, pls copy it from car to dup
# already searched for traveling-salesman-problem, pls copy it from car to dup
# already searched for halting-problem, pls copy it from car to dup
# already searched for P-problem, pls copy it from car to dup
# already searched for Sylvesters-problem, pls copy it from car to dup
# already searched for Sexual-problems, pls copy it from car to dup
# already searched for the-problem-of-tigers-in-america, pls copy it from car to dup
# already searched for urban-sprawl, pls copy it from car to dup
# already searched for continuum-problem, pls copy it from car to dup
# already searched for theodicy-theology, pls copy it from car to dup
# already searched for Y2K-bug, pls copy it from car to dup
# already searched for Deriving-solutions-from-models, pls copy it from car to dup
# already searched for three-wells-problem, pls copy it from car to dup
# already searched for four-color-map-problem, pls copy it from car to dup
# already searched for Substitution-problems, pls copy it from car to dup
# already searched for solid-problem, pls copy it from car to dup
# already searched for working-backward-approach, pls copy it from car to dup
# already searched for Warings-problem, pls copy it from car to dup
# already searched for Problems-and-directions, pls copy it from car to dup
# already searched for General-Problem-Solver, pls copy it from car to dup
# already searched for packing-combinatorics, pls copy it from car to dup
# already searched for means-ends-analysis, pls copy it from car to dup
# already searched for causes-and-solutions-2, pls copy it from car to dup
# already searched for algebra, pls copy it from car to dup
# already searched for Problems-with-the-gold-standard, pls copy it from car to dup
# already searched for philosophy-of-logic, pls copy it from car to dup
# already searched for n-body-problem, pls copy it from car to dup
# already searched for Problems-of-enumeration, pls copy it from car to dup
# already searched for two-cardinal-problem, pls copy it from car to dup
# already searched for Problems-not-solved-by-the-war, pls copy it from car to dup
# already searched for the-pros-and-cons-of-fish-farming, pls copy it from car to dup
# already searched for combinatorics, pls copy it from car to dup
# already searched for The-Kashmir-problem, pls copy it from car to dup
# already searched for primal-problem, pls copy it from car to dup
# already searched for Insight-and-reasoning, pls copy it from car to dup
# already searched for production-smoothing-problem, pls copy it from car to dup
# already searched for Russells-theory-of-descriptions, pls copy it from car to dup
# already searched for oddity-problem, pls copy it from car to dup
# already searched for determinism, pls copy it from car to dup
# already searched for species-problem, pls copy it from car to dup
# already searched for The-problem-of-particular-knowledge-of-God, pls copy it from car to dup
# already searched for Platos-problem, pls copy it from car to dup
# already searched for Problems-associated-with-the-use-of-coal, pls copy it from car to dup
# ____________________________________ remain: 0 _________________________________

# %%
remain_words
# Out:
# []

# %%
len(search_words)
# Out:
# 60

# %%
! ls
# Out:
# clustring.ipynb			       scarping_britinica.ipynb
# data				       scarping_wiki.ipynb
# information_scarping.ipynb	       scarping_wikipedia.ipynb
# most_similar.ipynb		       Untitled1.ipynb
# n_car.txt			       Untitled.ipynb
# ngram_search.txt		       web_scarpe_text_files
# not_stemmed_word_based_wiki_score.csv  wiki_data_processing.ipynb
# partial_data_based_wiki_score.csv      wiki_text.ipynb
# partial_data.csv		       word_file
# refine_text.ipynb

# %%
#URL = "https://www.britannica.com/technology/automobile"
web_text = ""
for el in set_links:
    page = requests.get(el)
    soup = BeautifulSoup(page.content, "html.parser")
    # getting all the paragraphs
    for para in soup.find_all("p"):
        web_text = web_text + para.get_text() + "\n"
#         print(para.get_text())

# %%
with open('web_scarpe_text_files/britannica.txt', 'w') as f:
    f.write(web_text)
